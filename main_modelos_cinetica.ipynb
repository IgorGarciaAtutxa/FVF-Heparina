# %% [markdown]
# # MODELOS INTELIGENCIA ARTIFICIAL

# %%
# Librerias estandar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.optimize import curve_fit
from scipy import stats
import math
import statistics
import modelos
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Librerias ANN
from sklearn import datasets
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import  GridSearchCV
from sklearn.metrics import mean_squared_error as MSE
from pyGRNN import GRNN

# %%
# Cargamos los datos
datos = pd.read_excel('Diclofenaco_IGA_mod.xlsx', sheet_name='HCl')

# %%
# Filtramos los datos por cantidad de entrecruzante, HCl
fil_01 = datos[datos['HCl']==1]
fil_05 = datos[datos['HCl']==5]
fil_10 = datos[datos['HCl']==10]
fil_20 = datos[datos['HCl']==20]
fil_30 = datos[datos['HCl']==30]
fil_40 = datos[datos['HCl']==40]

# Eje X
x = fil_01['Hora'].values.tolist()

# Eje Y
y_01 = fil_01['Media'].values.tolist()
y_01_1 = fil_01['Medida 1'].values.tolist()
y_01_2 = fil_01['Medida 2'].values.tolist()
y_01_3 = fil_01['Medida 3'].values.tolist()
y_01_4 = fil_01['Medida 4'].values.tolist()
y_05 = fil_05['Media'].values.tolist()
y_05_1 = fil_05['Medida 1'].values.tolist()
y_05_2 = fil_05['Medida 2'].values.tolist()
y_05_3 = fil_05['Medida 3'].values.tolist()
y_05_4 = fil_05['Medida 4'].values.tolist()
y_10 = fil_10['Media'].values.tolist()
y_10_1 = fil_10['Medida 1'].values.tolist()
y_10_2 = fil_10['Medida 2'].values.tolist()
y_10_3 = fil_10['Medida 3'].values.tolist()
y_10_4 = fil_10['Medida 4'].values.tolist()
y_20 = fil_20['Media'].values.tolist()
y_20_1 = fil_20['Medida 1'].values.tolist()
y_20_2 = fil_20['Medida 2'].values.tolist()
y_20_3 = fil_20['Medida 3'].values.tolist()
y_20_4 = fil_20['Medida 4'].values.tolist()
y_30 = fil_30['Media'].values.tolist()
y_30_1 = fil_30['Medida 1'].values.tolist()
y_30_2 = fil_30['Medida 2'].values.tolist()
y_30_3 = fil_30['Medida 3'].values.tolist()
y_30_4 = fil_30['Medida 4'].values.tolist()
y_40 = fil_40['Media'].values.tolist()
y_40_1 = fil_40['Medida 1'].values.tolist()
y_40_2 = fil_40['Medida 2'].values.tolist()
y_40_3 = fil_40['Medida 3'].values.tolist()
y_40_4 = fil_40['Medida 4'].values.tolist()

# %% [markdown]
# # MODELOS

# %% [markdown]
# ## MODELOS CLÁSICOS

# %% [markdown]
# ### ZERO-ORDER

# %% [markdown]
# #### HCl 1%

# %%
# Generamos la figura
fig, ax = plt.subplots()
# HCl 1%
ax.plot(x, y_01_1, marker = "o", color='b', label="Medida 1")
coef_1 = np.polyfit(x, y_01_1, 1)
ax.plot(x, y_01_2, marker = "o", color='g', label = "Medida 2")
coef_2 = np.polyfit(x, y_01_2, 1)
ax.plot(x, y_01_3, marker = "o", color= 'r', label = "Medida 3")
coef_3 = np.polyfit(x, y_01_3, 1)
ax.plot(x, y_01_4, marker = "o", color='y', label = "Medida 4")
coef_4 = np.polyfit(x, y_01_4, 1)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((coef_1[0]+coef_2[0]+coef_3[0])/3)
coef_123.append((coef_1[1]+coef_2[1]+coef_3[1])/3)
lin_fn = np.poly1d(coef_123)
y_pred_01_4 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_123)

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((coef_1[0]+coef_2[0]+coef_4[0])/3)
coef_124.append((coef_1[1]+coef_2[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_124)
y_pred_01_3 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_124)

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((coef_1[0]+coef_3[0]+coef_4[0])/3)
coef_134.append((coef_1[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_134)
y_pred_01_2 = lin_fn(x)
ax.plot(x, lin_fn(x), color='r')
print(coef_134)

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((coef_2[0]+coef_3[0]+coef_4[0])/3)
coef_234.append((coef_2[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_234)
y_pred_01_1 = lin_fn(x)
ax.plot(x, lin_fn(x), color='y')
print(coef_234)

ax.legend()
plt.show()
# Out:
# [1.2731176730549194, 53.103438452470215]
# [1.251394216819749, 52.671089851940884]
# [1.2519291455611083, 54.80691704081014]
# [1.2354709830355304, 51.76212045668772]

# %%
# Coeficientes interesantes
r_01_1_zero = r2_score(y_01_1, y_pred_01_1)
r_01_2_zero = r2_score(y_01_2, y_pred_01_2)
r_01_3_zero = r2_score(y_01_3, y_pred_01_3)
r_01_4_zero = r2_score(y_01_4, y_pred_01_4)

mse_1 = mean_squared_error(y_01_1, y_pred_01_1)
mse_2 = mean_squared_error(y_01_2, y_pred_01_2)
mse_3 = mean_squared_error(y_01_3, y_pred_01_3)
mse_4 = mean_squared_error(y_01_4, y_pred_01_4)

print('======================= R2 SCORE ZERO_ORDER =======================')
print('r2_01_1_zero =', r_01_1_zero, ' \t MSE =', mse_1)
print('r2_01_2_zero =', r_01_2_zero, ' \t MSE =', mse_2)
print('r2_01_3_zero =', r_01_3_zero, ' \t MSE =', mse_3)
print('r2_01_4_zero =', r_01_4_zero, ' \t MSE =', mse_4)
print('===================================================================')
# Out:
# ======================= R2 SCORE ZERO_ORDER =======================
# r2_01_1_zero = 0.9352198864350774  	 MSE = 868.8757761966555
# r2_01_2_zero = 0.9546663988528062  	 MSE = 559.8374309402668
# r2_01_3_zero = 0.9527438648237294  	 MSE = 587.9561656249846
# r2_01_4_zero = 0.9385159875556974  	 MSE = 688.6116656259919
# ...

# %% [markdown]
# #### HCl 5%

# %%
# Generamos la figura
fig, ax = plt.subplots()
# HCl 5%
ax.plot(x, y_05_1, marker = "o", color='b', label="Medida 1")
coef_1 = np.polyfit(x, y_05_1, 1)
ax.plot(x, y_05_2, marker = "o", color='g', label = "Medida 2")
coef_2 = np.polyfit(x, y_05_2, 1)
ax.plot(x, y_05_3, marker = "o", color= 'r', label = "Medida 3")
coef_3 = np.polyfit(x, y_05_3, 1)
ax.plot(x, y_05_4, marker = "o", color='y', label = "Medida 4")
coef_4 = np.polyfit(x, y_05_4, 1)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((coef_1[0]+coef_2[0]+coef_3[0])/3)
coef_123.append((coef_1[1]+coef_2[1]+coef_3[1])/3)
lin_fn = np.poly1d(coef_123)
y_pred_05_4 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_123)

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((coef_1[0]+coef_2[0]+coef_4[0])/3)
coef_124.append((coef_1[1]+coef_2[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_124)
y_pred_05_3 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_124)

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((coef_1[0]+coef_3[0]+coef_4[0])/3)
coef_134.append((coef_1[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_134)
y_pred_05_2 = lin_fn(x)
ax.plot(x, lin_fn(x), color='r')
print(coef_134)

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((coef_2[0]+coef_3[0]+coef_4[0])/3)
coef_234.append((coef_2[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_234)
y_pred_05_1 = lin_fn(x)
ax.plot(x, lin_fn(x), color='y')
print(coef_234)

ax.legend()
plt.show()
# Out:
# [1.2047478663095441, 43.697776297585044]
# [1.184218109346605, 44.63796442923266]
# [1.1871959500754619, 43.789867185008234]
# [1.159563992981994, 44.688206260941136]

# %%
# Coeficientes interesantes
r_05_1_zero = r2_score(y_05_1, y_pred_05_1)
r_05_2_zero = r2_score(y_05_2, y_pred_05_2)
r_05_3_zero = r2_score(y_05_3, y_pred_05_3)
r_05_4_zero = r2_score(y_05_4, y_pred_05_4)

mse_1 = mean_squared_error(y_05_1, y_pred_05_1)
mse_2 = mean_squared_error(y_05_2, y_pred_05_2)
mse_3 = mean_squared_error(y_05_3, y_pred_05_3)
mse_4 = mean_squared_error(y_05_4, y_pred_05_4)

print('======================= R2 SCORE ZERO_ORDER =======================')
print('r2_05_1_zero =', r_05_1_zero, ' \t MSE =', mse_1)
print('r2_05_2_zero =', r_05_2_zero, ' \t MSE =', mse_2)
print('r2_05_3_zero =', r_05_3_zero, ' \t MSE =', mse_3)
print('r2_05_4_zero =', r_05_4_zero, ' \t MSE =', mse_4)
print('===================================================================')
# Out:
# ======================= R2 SCORE ZERO_ORDER =======================
# r2_05_1_zero = 0.9448943873389282  	 MSE = 680.6222378825864
# r2_05_2_zero = 0.9503597995862947  	 MSE = 539.8210984679307
# r2_05_3_zero = 0.9509070618531501  	 MSE = 541.596486673943
# r2_05_4_zero = 0.940822713527271  	 MSE = 585.4247397309334
# ...

# %% [markdown]
# #### HCl 10%

# %%
# Generamos la figura
fig, ax = plt.subplots()
# HCl 10%
ax.plot(x, y_10_1, marker = "o", color='b', label="Medida 1")
coef_1 = np.polyfit(x, y_10_1, 1)
ax.plot(x, y_10_2, marker = "o", color='g', label = "Medida 2")
coef_2 = np.polyfit(x, y_10_2, 1)
ax.plot(x, y_10_3, marker = "o", color= 'r', label = "Medida 3")
coef_3 = np.polyfit(x, y_10_3, 1)
ax.plot(x, y_10_4, marker = "o", color='y', label = "Medida 4")
coef_4 = np.polyfit(x, y_10_4, 1)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((coef_1[0]+coef_2[0]+coef_3[0])/3)
coef_123.append((coef_1[1]+coef_2[1]+coef_3[1])/3)
lin_fn = np.poly1d(coef_123)
y_pred_10_4 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_123)

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((coef_1[0]+coef_2[0]+coef_4[0])/3)
coef_124.append((coef_1[1]+coef_2[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_124)
y_pred_10_3 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_124)

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((coef_1[0]+coef_3[0]+coef_4[0])/3)
coef_134.append((coef_1[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_134)
y_pred_10_2 = lin_fn(x)
ax.plot(x, lin_fn(x), color='r')
print(coef_134)

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((coef_2[0]+coef_3[0]+coef_4[0])/3)
coef_234.append((coef_2[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_234)
y_pred_10_1 = lin_fn(x)
ax.plot(x, lin_fn(x), color='y')
print(coef_234)

ax.legend()
plt.show()
# Out:
# [1.0845855322755868, 42.49286298936667]
# [1.085233512842286, 41.28095784263604]
# [1.08140045333746, 45.70771164259688]
# [1.0662713987929142, 42.54791357110264]

# %%
# Coeficientes interesantes
r_10_1_zero = r2_score(y_10_1, y_pred_10_1)
r_10_2_zero = r2_score(y_10_2, y_pred_10_2)
r_10_3_zero = r2_score(y_10_3, y_pred_10_3)
r_10_4_zero = r2_score(y_10_4, y_pred_10_4)

mse_1 = mean_squared_error(y_10_1, y_pred_10_1)
mse_2 = mean_squared_error(y_10_2, y_pred_10_2)
mse_3 = mean_squared_error(y_10_3, y_pred_10_3)
mse_4 = mean_squared_error(y_10_4, y_pred_10_4)

print('======================= R2 SCORE ZERO_ORDER =======================')
print('r2_10_1_zero =', r_10_1_zero, ' \t MSE =', mse_1)
print('r2_10_2_zero =', r_10_2_zero, ' \t MSE =', mse_2)
print('r2_10_3_zero =', r_10_3_zero, ' \t MSE =', mse_3)
print('r2_10_4_zero =', r_10_4_zero, ' \t MSE =', mse_4)
print('===================================================================')
# Out:
# ======================= R2 SCORE ZERO_ORDER =======================
# r2_10_1_zero = 0.935567342921903  	 MSE = 639.914685176824
# r2_10_2_zero = 0.9446471174337321  	 MSE = 497.8749049793104
# r2_10_3_zero = 0.9381771674841631  	 MSE = 555.6972399108319
# r2_10_4_zero = 0.9469875204485568  	 MSE = 474.71992201656815
# ...

# %% [markdown]
# #### HCl 20%

# %%
# Generamos la figura
fig, ax = plt.subplots()
# HCl 20%
ax.plot(x, y_20_1, marker = "o", color='b', label="Medida 1")
coef_1 = np.polyfit(x, y_20_1, 1)
ax.plot(x, y_20_2, marker = "o", color='g', label = "Medida 2")
coef_2 = np.polyfit(x, y_20_2, 1)
ax.plot(x, y_20_3, marker = "o", color= 'r', label = "Medida 3")
coef_3 = np.polyfit(x, y_20_3, 1)
ax.plot(x, y_20_4, marker = "o", color='y', label = "Medida 4")
coef_4 = np.polyfit(x, y_20_4, 1)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((coef_1[0]+coef_2[0]+coef_3[0])/3)
coef_123.append((coef_1[1]+coef_2[1]+coef_3[1])/3)
lin_fn = np.poly1d(coef_123)
y_pred_20_4 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_123)

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((coef_1[0]+coef_2[0]+coef_4[0])/3)
coef_124.append((coef_1[1]+coef_2[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_124)
y_pred_20_3 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_124)

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((coef_1[0]+coef_3[0]+coef_4[0])/3)
coef_134.append((coef_1[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_134)
y_pred_20_2 = lin_fn(x)
ax.plot(x, lin_fn(x), color='r')
print(coef_134)

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((coef_2[0]+coef_3[0]+coef_4[0])/3)
coef_234.append((coef_2[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_234)
y_pred_20_1 = lin_fn(x)
ax.plot(x, lin_fn(x), color='y')
print(coef_234)

ax.legend()
plt.show()
# Out:
# [0.9571636792680306, 24.296467633934736]
# [0.9431294758810896, 23.1683662451054]
# [0.9538261083204905, 25.377750707806857]
# [0.9332062439879798, 19.43923994844383]

# %%
# Coeficientes interesantes
r_20_1_zero = r2_score(y_20_1, y_pred_20_1)
r_20_2_zero = r2_score(y_20_2, y_pred_20_2)
r_20_3_zero = r2_score(y_20_3, y_pred_20_3)
r_20_4_zero = r2_score(y_20_4, y_pred_20_4)

mse_1 = mean_squared_error(y_20_1, y_pred_20_1)
mse_2 = mean_squared_error(y_20_2, y_pred_20_2)
mse_3 = mean_squared_error(y_20_3, y_pred_20_3)
mse_4 = mean_squared_error(y_20_4, y_pred_20_4)

print('======================= R2 SCORE ZERO_ORDER =======================')
print('r2_20_1_zero =', r_20_1_zero, ' \t MSE =', mse_1)
print('r2_20_2_zero =', r_20_2_zero, ' \t MSE =', mse_2)
print('r2_20_3_zero =', r_20_3_zero, ' \t MSE =', mse_3)
print('r2_20_4_zero =', r_20_4_zero, ' \t MSE =', mse_4)
print('===================================================================')
# Out:
# ======================= R2 SCORE ZERO_ORDER =======================
# r2_20_1_zero = 0.8932759031432544  	 MSE = 816.7768140085614
# r2_20_2_zero = 0.9506617763603804  	 MSE = 324.82918918232036
# r2_20_3_zero = 0.9644028284996979  	 MSE = 253.8119229178323
# r2_20_4_zero = 0.9458404962019185  	 MSE = 353.5410811379684
# ...

# %% [markdown]
# #### HCl 30%

# %%
# Generamos la figura
fig, ax = plt.subplots()
# HCl 30%
ax.plot(x, y_30_1, marker = "o", color='b', label="Medida 1")
coef_1 = np.polyfit(x, y_30_1, 1)
ax.plot(x, y_30_2, marker = "o", color='g', label = "Medida 2")
coef_2 = np.polyfit(x, y_30_2, 1)
ax.plot(x, y_30_3, marker = "o", color= 'r', label = "Medida 3")
coef_3 = np.polyfit(x, y_30_3, 1)
ax.plot(x, y_30_4, marker = "o", color='y', label = "Medida 4")
coef_4 = np.polyfit(x, y_30_4, 1)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((coef_1[0]+coef_2[0]+coef_3[0])/3)
coef_123.append((coef_1[1]+coef_2[1]+coef_3[1])/3)
lin_fn = np.poly1d(coef_123)
y_pred_30_4 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_123)

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((coef_1[0]+coef_2[0]+coef_4[0])/3)
coef_124.append((coef_1[1]+coef_2[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_124)
y_pred_30_3 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_124)

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((coef_1[0]+coef_3[0]+coef_4[0])/3)
coef_134.append((coef_1[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_134)
y_pred_30_2 = lin_fn(x)
ax.plot(x, lin_fn(x), color='r')
print(coef_134)

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((coef_2[0]+coef_3[0]+coef_4[0])/3)
coef_234.append((coef_2[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_234)
y_pred_30_1 = lin_fn(x)
ax.plot(x, lin_fn(x), color='y')
print(coef_234)

ax.legend()
plt.show()
# Out:
# [0.8407961688352557, 8.68493633539651]
# [0.8144499899071977, 8.224688092456418]
# [0.82080056851453, 10.362875399033634]
# [0.8340593901196341, 8.465512080441535]

# %%
# Coeficientes interesantes
r_30_1_zero = r2_score(y_30_1, y_pred_30_1)
r_30_2_zero = r2_score(y_30_2, y_pred_30_2)
r_30_3_zero = r2_score(y_30_3, y_pred_30_3)
r_30_4_zero = r2_score(y_30_4, y_pred_30_4)

mse_1 = mean_squared_error(y_30_1, y_pred_30_1)
mse_2 = mean_squared_error(y_30_2, y_pred_30_2)
mse_3 = mean_squared_error(y_30_3, y_pred_30_3)
mse_4 = mean_squared_error(y_30_4, y_pred_30_4)

print('======================= R2 SCORE ZERO_ORDER =======================')
print('r2_30_1_zero =', r_30_1_zero, ' \t MSE =', mse_1)
print('r2_30_2_zero =', r_30_2_zero, ' \t MSE =', mse_2)
print('r2_30_3_zero =', r_30_3_zero, ' \t MSE =', mse_3)
print('r2_30_4_zero =', r_30_4_zero, ' \t MSE =', mse_4)
print('===================================================================')
# Out:
# ======================= R2 SCORE ZERO_ORDER =======================
# r2_30_1_zero = 0.9766890469339894  	 MSE = 116.63832371309464
# r2_30_2_zero = 0.9805489297892618  	 MSE = 106.65985984863887
# r2_30_3_zero = 0.9549810029868596  	 MSE = 260.41001608317487
# r2_30_4_zero = 0.965370629120039  	 MSE = 164.98155926126017
# ...

# %% [markdown]
# #### HCl 40%

# %%
# Generamos la figura
fig, ax = plt.subplots()
# HCl 40%
ax.plot(x, y_40_1, marker = "o", color='b', label="Medida 1")
coef_1 = np.polyfit(x, y_40_1, 1)
ax.plot(x, y_40_2, marker = "o", color='g', label = "Medida 2")
coef_2 = np.polyfit(x, y_40_2, 1)
ax.plot(x, y_40_3, marker = "o", color= 'r', label = "Medida 3")
coef_3 = np.polyfit(x, y_40_3, 1)
ax.plot(x, y_40_4, marker = "o", color='y', label = "Medida 4")
coef_4 = np.polyfit(x, y_40_4, 1)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((coef_1[0]+coef_2[0]+coef_3[0])/3)
coef_123.append((coef_1[1]+coef_2[1]+coef_3[1])/3)
lin_fn = np.poly1d(coef_123)
y_pred_40_4 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_123)

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((coef_1[0]+coef_2[0]+coef_4[0])/3)
coef_124.append((coef_1[1]+coef_2[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_124)
y_pred_40_3 = lin_fn(x)
ax.plot(x, lin_fn(x), color='b')
print(coef_124)

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((coef_1[0]+coef_3[0]+coef_4[0])/3)
coef_134.append((coef_1[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_134)
y_pred_40_2 = lin_fn(x)
ax.plot(x, lin_fn(x), color='r')
print(coef_134)

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((coef_2[0]+coef_3[0]+coef_4[0])/3)
coef_234.append((coef_2[1]+coef_3[1]+coef_4[1])/3)
lin_fn = np.poly1d(coef_234)
y_pred_40_1 = lin_fn(x)
ax.plot(x, lin_fn(x), color='y')
print(coef_234)

ax.legend()
plt.show()
# Out:
# [0.7046048428578909, 0.9835542951727416]
# [0.710383135750695, 1.3291477669615268]
# [0.703220823574039, 3.8522604412814654]
# [0.7125943063069529, 1.3983455941978393]

# %%
# Coeficientes interesantes
r_40_1_zero = r2_score(y_40_1, y_pred_40_1)
r_40_2_zero = r2_score(y_40_2, y_pred_40_2)
r_40_3_zero = r2_score(y_40_3, y_pred_40_3)
r_40_4_zero = r2_score(y_40_4, y_pred_40_4)

mse_1 = mean_squared_error(y_40_1, y_pred_40_1)
mse_2 = mean_squared_error(y_40_2, y_pred_40_2)
mse_3 = mean_squared_error(y_40_3, y_pred_40_3)
mse_4 = mean_squared_error(y_40_4, y_pred_40_4)

print('======================= R2 SCORE ZERO_ORDER =======================')
print('r2_40_1_zero =', r_40_1_zero, ' \t MSE =', mse_1)
print('r2_40_2_zero =', r_40_2_zero, ' \t MSE =', mse_2)
print('r2_40_3_zero =', r_40_3_zero, ' \t MSE =', mse_3)
print('r2_40_4_zero =', r_40_4_zero, ' \t MSE =', mse_4)
print('===================================================================')
print('MEDIA_R2=', statistics.mean([r_40_1_zero, r_40_2_zero, r_40_3_zero, r_40_4_zero]))
print('SD_R2=', statistics.stdev([r_40_1_zero, r_40_2_zero, r_40_3_zero, r_40_4_zero]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================= R2 SCORE ZERO_ORDER =======================
# r2_40_1_zero = 0.987060192297991  	 MSE = 47.165158072927916
# r2_40_2_zero = 0.9796244905506664  	 MSE = 80.39475732878238
# r2_40_3_zero = 0.9814321676031813  	 MSE = 69.4045857914739
# r2_40_4_zero = 0.9753404349694196  	 MSE = 96.74083777140495
# ...
# MEDIA_R2= 0.9808643213553145
# SD_R2= 0.004856671264969777
# MEDIA_MSE= 73.42633474114729
# SD_MSE= 20.800231004497565

# %% [markdown]
# ### FIRST-ORDER

# %% [markdown]
# ##### HCl 1%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.first_order, x, y_01_1)
parametros_2, covarianza_2 = curve_fit(modelos.first_order, x, y_01_2)
parametros_3, covarianza_3 = curve_fit(modelos.first_order, x, y_01_3)
parametros_4, covarianza_4 = curve_fit(modelos.first_order, x, y_01_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
coef_123.append((parametros_1[2]+parametros_2[2]+parametros_3[2])/3)
y_pred_01_4 = np.array(modelos.first_order(x, coef_123[0], coef_123[1], coef_123[2]))
y_01_4 = np.array(y_01_4)
ax.plot(x, y_01_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_01_4, '-', label='Medida 1 fit', color='b')
r2_01_4 = r2_score(y_01_4, y_pred_01_4)
mse_4 = mean_squared_error(y_01_4, y_pred_01_4)
print(coef_123[0], coef_123[1], coef_123[2])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
coef_124.append((parametros_1[2]+parametros_2[2]+parametros_4[2])/3)
y_pred_01_3 = np.array(modelos.first_order(x, coef_124[0], coef_124[1], coef_124[2]))
y_01_3 = np.array(y_01_3)
ax.plot(x, y_01_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_01_3, '-', label='Medida 2 fit', color='g')
r2_01_3 = r2_score(y_01_3, y_pred_01_3)
mse_3 = mean_squared_error(y_01_3, y_pred_01_3)
print(coef_124[0], coef_124[1], coef_124[2])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
coef_134.append((parametros_1[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_01_2 = np.array(modelos.first_order(x, coef_134[0], coef_134[1], coef_134[2]))
y_01_2 = np.array(y_01_2)
ax.plot(x, y_01_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_01_2, '-', label='Medida 3 fit', color='r')
r2_01_2 = r2_score(y_01_2, y_pred_01_2)
mse_2 = mean_squared_error(y_01_2, y_pred_01_2)
print(coef_134[0], coef_134[1], coef_134[2])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
coef_234.append((parametros_2[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_01_1 = np.array(modelos.first_order(x, coef_234[0], coef_234[1], coef_234[2]))
y_01_1 = np.array(y_01_1)
ax.plot(x, y_01_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_01_1, '-', label='Medida 4 fit', color='y')
r2_01_1 = r2_score(y_01_1, y_pred_01_1)
mse_1 = mean_squared_error(y_01_1, y_pred_01_1)
print(coef_234[0], coef_234[1], coef_234[2])
# Out:
# c:\Users\igorg\OneDrive\Escritorio\UCAM\Proyectos\Ciencias de la salud\Liberacion_controlada_heparina\Python\modelos.py:40: RuntimeWarning: overflow encountered in exp
#   y = -a*np.exp(-b*x)+c
# 441.9903308086018 0.0059161045748976765 450.98423693107253
# 434.524925934636 0.005916142263685593 443.8414478331683
# 431.2257860371114 0.006042176635338142 441.68060179669584
# 429.4610821710458 0.00589929353212056 438.572827671637

# %%
print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_01_1_first =', r2_01_1, ' \t MSE =', mse_1)
print('r2_01_2_first =', r2_01_2, ' \t MSE =', mse_2)
print('r2_01_3_first =', r2_01_3, ' \t MSE =', mse_3)
print('r2_01_4_first =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('SD_R2=', statistics.stdev([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_01_1_first = 0.9804091610939375  	 MSE = 262.7659079941136
# r2_01_2_first = 0.99482080554436  	 MSE = 63.95933358506315
# r2_01_3_first = 0.9971675126832006  	 MSE = 35.241527385909954
# r2_01_4_first = 0.9829543715967936  	 MSE = 190.90846709145407
# ...
# MEDIA_R2= 0.9888379627295729
# SD_R2= 0.008383260149588559
# MEDIA_MSE= 138.2188090141352
# SD_MSE= 107.09337071791307

# %% [markdown]
# #### HCl 5%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.first_order, x, y_05_1)
parametros_2, covarianza_2 = curve_fit(modelos.first_order, x, y_05_2)
parametros_3, covarianza_3 = curve_fit(modelos.first_order, x, y_05_3)
parametros_4, covarianza_4 = curve_fit(modelos.first_order, x, y_05_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
coef_123.append((parametros_1[2]+parametros_2[2]+parametros_3[2])/3)
y_pred_05_4 = np.array(modelos.first_order(x, coef_123[0], coef_123[1], coef_123[2]))
y_05_4 = np.array(y_05_4)
ax.plot(x, y_05_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_05_4, '-', label='Medida 1 fit', color='b')
r2_05_4 = r2_score(y_05_4, y_pred_05_4)
mse_4 = mean_squared_error(y_05_4, y_pred_05_4)
print(coef_123[0], coef_123[1], coef_123[2])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
coef_124.append((parametros_1[2]+parametros_2[2]+parametros_4[2])/3)
y_pred_05_3 = np.array(modelos.first_order(x, coef_124[0], coef_124[1], coef_124[2]))
y_05_3 = np.array(y_05_3)
ax.plot(x, y_05_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_05_3, '-', label='Medida 2 fit', color='g')
r2_05_3 = r2_score(y_05_3, y_pred_05_3)
mse_3 = mean_squared_error(y_05_3, y_pred_05_3)
print(coef_124[0], coef_124[1], coef_124[2])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
coef_134.append((parametros_1[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_05_2 = np.array(modelos.first_order(x, coef_134[0], coef_134[1], coef_134[2]))
y_05_2 = np.array(y_05_2)
ax.plot(x, y_05_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_05_2, '-', label='Medida 3 fit', color='r')
r2_05_2 = r2_score(y_05_2, y_pred_05_2)
mse_2 = mean_squared_error(y_05_2, y_pred_05_2)
print(coef_134[0], coef_134[1], coef_134[2])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
coef_234.append((parametros_2[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_05_1 = np.array(modelos.first_order(x, coef_234[0], coef_234[1], coef_234[2]))
y_05_1 = np.array(y_05_1)
ax.plot(x, y_05_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_05_1, '-', label='Medida 4 fit', color='y')
r2_05_1 = r2_score(y_05_1, y_pred_05_1)
mse_1 = mean_squared_error(y_05_1, y_pred_05_1)
print(coef_234[0], coef_234[1], coef_234[2])
# Out:
# c:\Users\igorg\OneDrive\Escritorio\UCAM\Proyectos\Ciencias de la salud\Liberacion_controlada_heparina\Python\modelos.py:40: RuntimeWarning: overflow encountered in exp
#   y = -a*np.exp(-b*x)+c
# 417.49897463291796 0.005972967913100132 419.04614019242644
# 411.6697277286974 0.005914641649606798 415.34741365010933
# 413.6799078987408 0.005871681294921269 416.69903347314795
# 398.4425259755465 0.006091357330175621 401.6262398386245

# %%
print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_05_1_first =', r2_05_1, ' \t MSE =', mse_1)
print('r2_05_2_first =', r2_05_2, ' \t MSE =', mse_2)
print('r2_05_3_first =', r2_05_3, ' \t MSE =', mse_3)
print('r2_05_4_first =', r2_05_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_05_1, r2_05_2, r2_05_3, r2_05_4]))
print('SD_R2=', statistics.stdev([r2_05_1, r2_05_2, r2_05_3, r2_05_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_05_1_first = 0.984225006674642  	 MSE = 194.84061134979132
# r2_05_2_first = 0.9979001676245086  	 MSE = 22.83499683904057
# r2_05_3_first = 0.9974618283699697  	 MSE = 28.00127450689414
# r2_05_4_first = 0.9827561876447337  	 MSE = 170.58832808602895
# ...
# MEDIA_R2= 0.9905857975784635
# SD_R2= 0.008216695630497737
# MEDIA_MSE= 104.06630269543875
# SD_MSE= 91.37754745778963

# %% [markdown]
# #### HCl 10%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.first_order, x, y_10_1)
parametros_2, covarianza_2 = curve_fit(modelos.first_order, x, y_10_2)
parametros_3, covarianza_3 = curve_fit(modelos.first_order, x, y_10_3)
parametros_4, covarianza_4 = curve_fit(modelos.first_order, x, y_10_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
coef_123.append((parametros_1[2]+parametros_2[2]+parametros_3[2])/3)
y_pred_10_4 = np.array(modelos.first_order(x, coef_123[0], coef_123[1], coef_123[2]))
y_10_4 = np.array(y_10_4)
ax.plot(x, y_10_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_10_4, '-', label='Medida 1 fit', color='b')
r2_10_4 = r2_score(y_10_4, y_pred_10_4)
mse_4 = mean_squared_error(y_10_4, y_pred_10_4)
print(coef_123[0], coef_123[1], coef_123[2])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
coef_124.append((parametros_1[2]+parametros_2[2]+parametros_4[2])/3)
y_pred_10_3 = np.array(modelos.first_order(x, coef_124[0], coef_124[1], coef_124[2]))
y_10_3 = np.array(y_10_3)
ax.plot(x, y_10_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_10_3, '-', label='Medida 2 fit', color='g')
r2_10_3 = r2_score(y_10_3, y_pred_10_3)
mse_3 = mean_squared_error(y_10_3, y_pred_10_3)
print(coef_124[0], coef_124[1], coef_124[2])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
coef_134.append((parametros_1[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_10_2 = np.array(modelos.first_order(x, coef_134[0], coef_134[1], coef_134[2]))
y_10_2 = np.array(y_10_2)
ax.plot(x, y_10_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_10_2, '-', label='Medida 3 fit', color='r')
r2_10_2 = r2_score(y_10_2, y_pred_10_2)
mse_2 = mean_squared_error(y_10_2, y_pred_10_2)
print(coef_134[0], coef_134[1], coef_134[2])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
coef_234.append((parametros_2[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_10_1 = np.array(modelos.first_order(x, coef_234[0], coef_234[1], coef_234[2]))
y_10_1 = np.array(y_10_1)
ax.plot(x, y_10_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_10_1, '-', label='Medida 4 fit', color='y')
r2_10_1 = r2_score(y_10_1, y_pred_10_1)
mse_1 = mean_squared_error(y_10_1, y_pred_10_1)
print(coef_234[0], coef_234[1], coef_234[2])
# Out:
# c:\Users\igorg\OneDrive\Escritorio\UCAM\Proyectos\Ciencias de la salud\Liberacion_controlada_heparina\Python\modelos.py:40: RuntimeWarning: overflow encountered in exp
#   y = -a*np.exp(-b*x)+c
# 370.1794556125569 0.006312570590066856 372.266113800141
# 372.9332391633349 0.006149251812960207 374.91628033880005
# 361.6871480190942 0.006640082125188571 364.8943409964541
# 365.1070082972451 0.0062481146617547325 368.4173299252382

# %%
print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_10_1_first =', r2_10_1, ' \t MSE =', mse_1)
print('r2_10_2_first =', r2_10_2, ' \t MSE =', mse_2)
print('r2_10_3_first =', r2_10_3, ' \t MSE =', mse_3)
print('r2_10_4_first =', r2_10_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_10_1, r2_10_2, r2_10_3, r2_10_4]))
print('SD_R2=', statistics.stdev([r2_10_1, r2_10_2, r2_10_3, r2_10_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_10_1_first = 0.9898991290834522  	 MSE = 100.31707406913124
# r2_10_2_first = 0.980530922175554  	 MSE = 175.1158173248932
# r2_10_3_first = 0.9952819344837394  	 MSE = 42.4085386969759
# r2_10_4_first = 0.9965296979148305  	 MSE = 31.076107912419612
# ...
# MEDIA_R2= 0.990560420914394
# SD_R2= 0.007279036340329557
# MEDIA_MSE= 87.22938450085499
# SD_MSE= 65.97325564944776

# %% [markdown]
# #### HCl 20%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.first_order, x, y_20_1)
parametros_2, covarianza_2 = curve_fit(modelos.first_order, x, y_20_2)
parametros_3, covarianza_3 = curve_fit(modelos.first_order, x, y_20_3)
parametros_4, covarianza_4 = curve_fit(modelos.first_order, x, y_20_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
coef_123.append((parametros_1[2]+parametros_2[2]+parametros_3[2])/3)
y_pred_20_4 = np.array(modelos.first_order(x, coef_123[0], coef_123[1], coef_123[2]))
y_20_4 = np.array(y_20_4)
ax.plot(x, y_20_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_20_4, '-', label='Medida 1 fit', color='b')
r2_20_4 = r2_score(y_20_4, y_pred_20_4)
mse_4 = mean_squared_error(y_20_4, y_pred_20_4)
print(coef_123[0], coef_123[1], coef_123[2])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
coef_124.append((parametros_1[2]+parametros_2[2]+parametros_4[2])/3)
y_pred_20_3 = np.array(modelos.first_order(x, coef_124[0], coef_124[1], coef_124[2]))
y_20_3 = np.array(y_20_3)
ax.plot(x, y_20_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_20_3, '-', label='Medida 2 fit', color='g')
r2_20_3 = r2_score(y_20_3, y_pred_20_3)
mse_3 = mean_squared_error(y_20_3, y_pred_20_3)
print(coef_124[0], coef_124[1], coef_124[2])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
coef_134.append((parametros_1[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_20_2 = np.array(modelos.first_order(x, coef_134[0], coef_134[1], coef_134[2]))
y_20_2 = np.array(y_20_2)
ax.plot(x, y_20_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_20_2, '-', label='Medida 3 fit', color='r')
r2_20_2 = r2_score(y_20_2, y_pred_20_2)
mse_2 = mean_squared_error(y_20_2, y_pred_20_2)
print(coef_134[0], coef_134[1], coef_134[2])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
coef_234.append((parametros_2[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_20_1 = np.array(modelos.first_order(x, coef_234[0], coef_234[1], coef_234[2]))
y_20_1 = np.array(y_20_1)
ax.plot(x, y_20_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_20_1, '-', label='Medida 4 fit', color='y')
r2_20_1 = r2_score(y_20_1, y_pred_20_1)
mse_1 = mean_squared_error(y_20_1, y_pred_20_1)
print(coef_234[0], coef_234[1], coef_234[2])
# Out:
# c:\Users\igorg\OneDrive\Escritorio\UCAM\Proyectos\Ciencias de la salud\Liberacion_controlada_heparina\Python\modelos.py:40: RuntimeWarning: overflow encountered in exp
#   y = -a*np.exp(-b*x)+c
# 363.2187366973355 0.004861950167821671 360.4725216448158
# 358.1728866532042 0.0048584672932551415 354.6965233433095
# 348.7475492750009 0.005195965280913782 345.24912265895153
# 360.33876709670375 0.004644775170889965 354.76590698681747

# %%
print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_20_1_first =', r2_20_1, ' \t MSE =', mse_1)
print('r2_20_2_first =', r2_20_2, ' \t MSE =', mse_2)
print('r2_20_3_first =', r2_20_3, ' \t MSE =', mse_3)
print('r2_20_4_first =', r2_20_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_20_1, r2_20_2, r2_20_3, r2_20_4]))
print('SD_R2=', statistics.stdev([r2_20_1, r2_20_2, r2_20_3, r2_20_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_20_1_first = 0.9379088635331422  	 MSE = 475.1935328124117
# r2_20_2_first = 0.969414287524797  	 MSE = 201.36785337982164
# r2_20_3_first = 0.9976049625290676  	 MSE = 17.0768923579352
# r2_20_4_first = 0.9743017583861162  	 MSE = 167.75235159815114
# ...
# MEDIA_R2= 0.9698074679932808
# SD_R2= 0.024566745178441273
# MEDIA_MSE= 215.34765753707993
# SD_MSE= 190.86812488733537

# %% [markdown]
# #### HCl 30%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.first_order, x, y_30_1)
parametros_2, covarianza_2 = curve_fit(modelos.first_order, x, y_30_2)
parametros_3, covarianza_3 = curve_fit(modelos.first_order, x, y_30_3)
parametros_4, covarianza_4 = curve_fit(modelos.first_order, x, y_30_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
coef_123.append((parametros_1[2]+parametros_2[2]+parametros_3[2])/3)
y_pred_30_4 = np.array(modelos.first_order(x, coef_123[0], coef_123[1], coef_123[2]))
y_30_4 = np.array(y_30_4)
ax.plot(x, y_30_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_30_4, '-', label='Medida 1 fit', color='b')
r2_30_4 = r2_score(y_30_4, y_pred_30_4)
mse_4 = mean_squared_error(y_30_4, y_pred_30_4)
print(coef_123[0], coef_123[1], coef_123[2])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
coef_124.append((parametros_1[2]+parametros_2[2]+parametros_4[2])/3)
y_pred_30_3 = np.array(modelos.first_order(x, coef_124[0], coef_124[1], coef_124[2]))
y_30_3 = np.array(y_30_3)
ax.plot(x, y_30_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_30_3, '-', label='Medida 2 fit', color='g')
r2_30_3 = r2_score(y_30_3, y_pred_30_3)
mse_3 = mean_squared_error(y_30_3, y_pred_30_3)
print(coef_124[0], coef_124[1], coef_124[2])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
coef_134.append((parametros_1[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_30_2 = np.array(modelos.first_order(x, coef_134[0], coef_134[1], coef_134[2]))
y_30_2 = np.array(y_30_2)
ax.plot(x, y_30_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_30_2, '-', label='Medida 3 fit', color='r')
r2_30_2 = r2_score(y_30_2, y_pred_30_2)
mse_2 = mean_squared_error(y_30_2, y_pred_30_2)
print(coef_134[0], coef_134[1], coef_134[2])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
coef_234.append((parametros_2[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_30_1 = np.array(modelos.first_order(x, coef_234[0], coef_234[1], coef_234[2]))
y_30_1 = np.array(y_30_1)
ax.plot(x, y_30_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_30_1, '-', label='Medida 4 fit', color='y')
r2_30_1 = r2_score(y_30_1, y_pred_30_1)
mse_1 = mean_squared_error(y_30_1, y_pred_30_1)
print(coef_234[0], coef_234[1], coef_234[2])
# Out:
# c:\Users\igorg\OneDrive\Escritorio\UCAM\Proyectos\Ciencias de la salud\Liberacion_controlada_heparina\Python\modelos.py:40: RuntimeWarning: overflow encountered in exp
#   y = -a*np.exp(-b*x)+c
# 392.5767024256943 0.0033011020045903977 385.5723986483302
# 389.88392200909584 0.003149049006061685 383.7129167989074
# 365.7773496794198 0.003505493676122563 359.79907529032306
# 389.97625551062055 0.0032937887917526237 382.9144333572194

# %%
print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_30_1_first =', r2_30_1, ' \t MSE =', mse_1)
print('r2_30_2_first =', r2_30_2, ' \t MSE =', mse_2)
print('r2_30_3_first =', r2_30_3, ' \t MSE =', mse_3)
print('r2_30_4_first =', r2_30_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_30_1, r2_30_2, r2_30_3, r2_30_4]))
print('SD_R2=', statistics.stdev([r2_30_1, r2_30_2, r2_30_3, r2_30_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_30_1_first = 0.9911512752849836  	 MSE = 44.2753419319878
# r2_30_2_first = 0.9911285678521169  	 MSE = 48.64646003012972
# r2_30_3_first = 0.9787299634624009  	 MSE = 123.03540559175845
# r2_30_4_first = 0.9760677505595736  	 MSE = 114.01823737998609
# ...
# MEDIA_R2= 0.9842693892897687
# SD_R2= 0.008007513175321805
# MEDIA_MSE= 82.49386123346551
# SD_MSE= 41.80791351008303

# %% [markdown]
# #### HCl 40%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.first_order, x, y_40_1)
parametros_2, covarianza_2 = curve_fit(modelos.first_order, x, y_40_2)
parametros_3, covarianza_3 = curve_fit(modelos.first_order, x, y_40_3)
parametros_4, covarianza_4 = curve_fit(modelos.first_order, x, y_40_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
coef_123.append((parametros_1[2]+parametros_2[2]+parametros_3[2])/3)
y_pred_40_4 = np.array(modelos.first_order(x, coef_123[0], coef_123[1], coef_123[2]))
y_40_4 = np.array(y_40_4)
ax.plot(x, y_40_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_40_4, '-', label='Medida 1 fit', color='b')
r2_40_4 = r2_score(y_40_4, y_pred_40_4)
mse_4 = mean_squared_error(y_40_4, y_pred_40_4)
print(coef_123[0], coef_123[1], coef_123[2])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
coef_124.append((parametros_1[2]+parametros_2[2]+parametros_4[2])/3)
y_pred_40_3 = np.array(modelos.first_order(x, coef_124[0], coef_124[1], coef_124[2]))
y_40_3 = np.array(y_40_3)
ax.plot(x, y_40_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_40_3, '-', label='Medida 2 fit', color='g')
r2_40_3 = r2_score(y_40_3, y_pred_40_3)
mse_3 = mean_squared_error(y_40_3, y_pred_40_3)
print(coef_124[0], coef_124[1], coef_124[2])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
coef_134.append((parametros_1[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_40_2 = np.array(modelos.first_order(x, coef_134[0], coef_134[1], coef_134[2]))
y_40_2 = np.array(y_40_2)
ax.plot(x, y_40_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_40_2, '-', label='Medida 3 fit', color='r')
r2_40_2 = r2_score(y_40_2, y_pred_40_2)
mse_2 = mean_squared_error(y_40_2, y_pred_40_2)
print(coef_134[0], coef_134[1], coef_134[2])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
coef_234.append((parametros_2[2]+parametros_3[2]+parametros_4[2])/3)
y_pred_40_1 = np.array(modelos.first_order(x, coef_234[0], coef_234[1], coef_234[2]))
y_40_1 = np.array(y_40_1)
ax.plot(x, y_40_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_40_1, '-', label='Medida 4 fit', color='y')
r2_40_1 = r2_score(y_40_1, y_pred_40_1)
mse_1 = mean_squared_error(y_40_1, y_pred_40_1)
print(coef_234[0], coef_234[1], coef_234[2])
# Out:
# c:\Users\igorg\OneDrive\Escritorio\UCAM\Proyectos\Ciencias de la salud\Liberacion_controlada_heparina\Python\modelos.py:40: RuntimeWarning: overflow encountered in exp
#   y = -a*np.exp(-b*x)+c
# 496.62097347783646 0.00201158117405318 489.81969141226773
# 499.01127870865093 0.002018629949921969 492.4399803219804
# 391.2899171053421 0.00249804077016653 385.37386269344546
# 480.6726591146121 0.002187104844883938 473.4570260578067

# %%
print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_40_1_first =', r2_40_1, ' \t MSE =', mse_1)
print('r2_40_2_first =', r2_40_2, ' \t MSE =', mse_2)
print('r2_40_3_first =', r2_40_3, ' \t MSE =', mse_3)
print('r2_40_4_first =', r2_40_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_40_1, r2_40_2, r2_40_3, r2_40_4]))
print('SD_R2=', statistics.stdev([r2_40_1, r2_40_2, r2_40_3, r2_40_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_40_1_first = 0.9397846798336635  	 MSE = 219.4827898111875
# r2_40_2_first = 0.978023397765216  	 MSE = 86.7121191727761
# r2_40_3_first = 0.9645648988133791  	 MSE = 132.4526454018276
# r2_40_4_first = 0.9844339263957179  	 MSE = 61.066567858036606
# ...
# MEDIA_R2= 0.9667017257019941
# SD_R2= 0.01976279827672317
# MEDIA_MSE= 124.92853056095694
# SD_MSE= 69.60834391114878

# %% [markdown]
# ### HIGUCHI

# %% [markdown]
# #### HCl 1%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.higuchi, x, y_01_1)
parametros_2, covarianza_2 = curve_fit(modelos.higuchi, x, y_01_2)
parametros_3, covarianza_3 = curve_fit(modelos.higuchi, x, y_01_3)
parametros_4, covarianza_4 = curve_fit(modelos.higuchi, x, y_01_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_01_4 = np.array(modelos.higuchi(x, coef_123[0], coef_123[1]))
y_01_4 = np.array(y_01_4)
ax.plot(x, y_01_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_01_4, '-', label='Medida 1 fit', color='b')
r2_01_4 = r2_score(y_01_4, y_pred_01_4)
mse_4 = mean_squared_error(y_01_4, y_pred_01_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_01_3 = np.array(modelos.higuchi(x, coef_124[0], coef_124[1]))
y_01_3 = np.array(y_01_3)
ax.plot(x, y_01_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_01_3, '-', label='Medida 2 fit', color='g')
r2_01_3 = r2_score(y_01_3, y_pred_01_3)
mse_3 = mean_squared_error(y_01_3, y_pred_01_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_01_2 = np.array(modelos.higuchi(x, coef_134[0], coef_134[1]))
y_01_2 = np.array(y_01_2)
ax.plot(x, y_01_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_01_2, '-', label='Medida 3 fit', color='r')
r2_01_2 = r2_score(y_01_2, y_pred_01_2)
mse_2 = mean_squared_error(y_01_2, y_pred_01_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_01_1 = np.array(modelos.higuchi(x, coef_234[0], coef_234[1]))
y_01_1 = np.array(y_01_1)
ax.plot(x, y_01_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_01_1, '-', label='Medida 4 fit', color='y')
r2_01_1 = r2_score(y_01_1, y_pred_01_1)
mse_1 = mean_squared_error(y_01_1, y_pred_01_1)
print(coef_234[0], coef_234[1])
# Out:
# 24.979407433674467 -43.3592791836539
# 24.555134142352575 -42.16569007524697
# 24.59291286500161 -40.349813928893035
# 24.239690144818038 -41.83724773467312

# %%
print('======================== R2 SCORE HIGUCHI ========================')
print('r2_01_1_Higuchi =', r2_01_1, ' \t MSE =', mse_1)
print('r2_01_2_Higuchi =', r2_01_2, ' \t MSE =', mse_2)
print('r2_01_3_Higuchi =', r2_01_3, ' \t MSE =', mse_3)
print('r2_01_4_Higuchi =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('SD_R2=', statistics.stdev([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE HIGUCHI ========================
# r2_01_1_Higuchi = 0.9772688278249632  	 MSE = 304.88623407013444
# r2_01_2_Higuchi = 0.9899623757311593  	 MSE = 123.95745410045163
# r2_01_3_Higuchi = 0.9944337313788815  	 MSE = 69.25496431529861
# r2_01_4_Higuchi = 0.9807591289923004  	 MSE = 215.49485314917226
# ...
# MEDIA_R2= 0.9856060159818261
# SD_R2= 0.007956285759263713
# MEDIA_MSE= 178.39837640876422
# SD_MSE= 103.68449763183577

# %% [markdown]
# #### HCl 5%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.higuchi, x, y_05_1)
parametros_2, covarianza_2 = curve_fit(modelos.higuchi, x, y_05_2)
parametros_3, covarianza_3 = curve_fit(modelos.higuchi, x, y_05_3)
parametros_4, covarianza_4 = curve_fit(modelos.higuchi, x, y_05_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_05_4 = np.array(modelos.higuchi(x, coef_123[0], coef_123[1]))
y_05_4 = np.array(y_05_4)
ax.plot(x, y_05_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_05_4, '-', label='Medida 1 fit', color='b')
r2_05_4 = r2_score(y_05_4, y_pred_05_4)
mse_4 = mean_squared_error(y_05_4, y_pred_05_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_05_3 = np.array(modelos.higuchi(x, coef_124[0], coef_124[1]))
y_05_3 = np.array(y_05_3)
ax.plot(x, y_05_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_05_3, '-', label='Medida 2 fit', color='g')
r2_05_3 = r2_score(y_05_3, y_pred_05_3)
mse_3 = mean_squared_error(y_05_3, y_pred_05_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_05_2 = np.array(modelos.higuchi(x, coef_134[0], coef_134[1]))
y_05_2 = np.array(y_05_2)
ax.plot(x, y_05_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_05_2, '-', label='Medida 3 fit', color='r')
r2_05_2 = r2_score(y_05_2, y_pred_05_2)
mse_2 = mean_squared_error(y_05_2, y_pred_05_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_05_1 = np.array(modelos.higuchi(x, coef_234[0], coef_234[1]))
y_05_1 = np.array(y_05_1)
ax.plot(x, y_05_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_05_1, '-', label='Medida 4 fit', color='y')
r2_05_1 = r2_score(y_05_1, y_pred_05_1)
mse_1 = mean_squared_error(y_05_1, y_pred_05_1)
print(coef_234[0], coef_234[1])
# Out:
# 23.622769647621908 -47.429199753798116
# 23.219842812968896 -44.932271040509285
# 23.268950509184588 -45.910550121902894
# 22.767302276286514 -43.333441599204605

# %%
print('======================== R2 SCORE HIGUCHI ========================')
print('r2_05_1_Higuchi =', r2_05_1, ' \t MSE =', mse_1)
print('r2_05_2_Higuchi =', r2_05_2, ' \t MSE =', mse_2)
print('r2_05_3_Higuchi =', r2_05_3, ' \t MSE =', mse_3)
print('r2_05_4_Higuchi =', r2_05_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_05_1, r2_05_2, r2_05_3, r2_05_4]))
print('SD_R2=', statistics.stdev([r2_05_1, r2_05_2, r2_05_3, r2_05_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE HIGUCHI ========================
# r2_05_1_Higuchi = 0.9782502183270829  	 MSE = 268.636611786299
# r2_05_2_Higuchi = 0.9930171904058632  	 MSE = 75.93579224266428
# r2_05_3_Higuchi = 0.9911422057311553  	 MSE = 97.71976249082444
# r2_05_4_Higuchi = 0.9810639555221172  	 MSE = 187.32911849728916
# ...
# MEDIA_R2= 0.9858683924965547
# SD_R2= 0.007303825707562016
# MEDIA_MSE= 157.4053212542692
# SD_MSE= 88.44486741682555

# %% [markdown]
# #### HCl 10%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.higuchi, x, y_10_1)
parametros_2, covarianza_2 = curve_fit(modelos.higuchi, x, y_10_2)
parametros_3, covarianza_3 = curve_fit(modelos.higuchi, x, y_10_3)
parametros_4, covarianza_4 = curve_fit(modelos.higuchi, x, y_10_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_10_4 = np.array(modelos.higuchi(x, coef_123[0], coef_123[1]))
y_10_4 = np.array(y_10_4)
ax.plot(x, y_10_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_10_4, '-', label='Medida 1 fit', color='b')
r2_10_4 = r2_score(y_10_4, y_pred_10_4)
mse_4 = mean_squared_error(y_10_4, y_pred_10_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_10_3 = np.array(modelos.higuchi(x, coef_124[0], coef_124[1]))
y_10_3 = np.array(y_10_3)
ax.plot(x, y_10_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_10_3, '-', label='Medida 2 fit', color='g')
r2_10_3 = r2_score(y_10_3, y_pred_10_3)
mse_3 = mean_squared_error(y_10_3, y_pred_10_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_10_2 = np.array(modelos.higuchi(x, coef_134[0], coef_134[1]))
y_10_2 = np.array(y_10_2)
ax.plot(x, y_10_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_10_2, '-', label='Medida 3 fit', color='r')
r2_10_2 = r2_score(y_10_2, y_pred_10_2)
mse_2 = mean_squared_error(y_10_2, y_pred_10_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_10_1 = np.array(modelos.higuchi(x, coef_234[0], coef_234[1]))
y_10_1 = np.array(y_10_1)
ax.plot(x, y_10_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_10_1, '-', label='Medida 4 fit', color='y')
r2_10_1 = r2_score(y_10_1, y_pred_10_1)
mse_1 = mean_squared_error(y_10_1, y_pred_10_1)
print(coef_234[0], coef_234[1])
# Out:
# 21.320797213854384 -40.09991378797728
# 21.309534788948863 -41.115362669031306
# 21.313964116518267 -37.2137807725536
# 20.95535893896161 -38.59471848436068

# %%
print('======================== R2 SCORE HIGUCHI ========================')
print('r2_10_1_Higuchi =', r2_10_1, ' \t MSE =', mse_1)
print('r2_10_2_Higuchi =', r2_10_2, ' \t MSE =', mse_2)
print('r2_10_3_Higuchi =', r2_10_3, ' \t MSE =', mse_3)
print('r2_10_4_Higuchi =', r2_10_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_10_1, r2_10_2, r2_10_3, r2_10_4]))
print('SD_R2=', statistics.stdev([r2_10_1, r2_10_2, r2_10_3, r2_10_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE HIGUCHI ========================
# r2_10_1_Higuchi = 0.9822414620154348  	 MSE = 176.36940270552233
# r2_10_2_Higuchi = 0.9748927783454425  	 MSE = 225.82844860142686
# r2_10_3_Higuchi = 0.9906110493389013  	 MSE = 84.39299455739086
# r2_10_4_Higuchi = 0.9927813294318791  	 MSE = 64.64226457915893
# ...
# MEDIA_R2= 0.9851316547829144
# SD_R2= 0.008200184792027571
# MEDIA_MSE= 137.80827761087474
# SD_MSE= 76.24733612048817

# %% [markdown]
# #### HCl 20%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.higuchi, x, y_20_1)
parametros_2, covarianza_2 = curve_fit(modelos.higuchi, x, y_20_2)
parametros_3, covarianza_3 = curve_fit(modelos.higuchi, x, y_20_3)
parametros_4, covarianza_4 = curve_fit(modelos.higuchi, x, y_20_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_20_4 = np.array(modelos.higuchi(x, coef_123[0], coef_123[1]))
y_20_4 = np.array(y_20_4)
ax.plot(x, y_20_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_20_4, '-', label='Medida 1 fit', color='b')
r2_20_4 = r2_score(y_20_4, y_pred_20_4)
mse_4 = mean_squared_error(y_20_4, y_pred_20_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_20_3 = np.array(modelos.higuchi(x, coef_124[0], coef_124[1]))
y_20_3 = np.array(y_20_3)
ax.plot(x, y_20_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_20_3, '-', label='Medida 2 fit', color='g')
r2_20_3 = r2_score(y_20_3, y_pred_20_3)
mse_3 = mean_squared_error(y_20_3, y_pred_20_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_20_2 = np.array(modelos.higuchi(x, coef_134[0], coef_134[1]))
y_20_2 = np.array(y_20_2)
ax.plot(x, y_20_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_20_2, '-', label='Medida 3 fit', color='r')
r2_20_2 = r2_score(y_20_2, y_pred_20_2)
mse_2 = mean_squared_error(y_20_2, y_pred_20_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_20_1 = np.array(modelos.higuchi(x, coef_234[0], coef_234[1]))
y_20_1 = np.array(y_20_1)
ax.plot(x, y_20_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_20_1, '-', label='Medida 4 fit', color='y')
r2_20_1 = r2_score(y_20_1, y_pred_20_1)
mse_1 = mean_squared_error(y_20_1, y_pred_20_1)
print(coef_234[0], coef_234[1])
# Out:
# 18.603042329980678 -46.41258663104801
# 18.323073709486025 -46.43013591749884
# 18.57926605882331 -45.50558376224072
# 18.092008235840254 -49.03495573837946

# %%
print('======================== R2 SCORE HIGUCHI ========================')
print('r2_20_1_Higuchi =', r2_20_1, ' \t MSE =', mse_1)
print('r2_20_2_Higuchi =', r2_20_2, ' \t MSE =', mse_2)
print('r2_20_3_Higuchi =', r2_20_3, ' \t MSE =', mse_3)
print('r2_20_4_Higuchi =', r2_20_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_20_1, r2_20_2, r2_20_3, r2_20_4]))
print('SD_R2=', statistics.stdev([r2_20_1, r2_20_2, r2_20_3, r2_20_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE HIGUCHI ========================
# r2_20_1_Higuchi = 0.9260701212472592  	 MSE = 565.7973466737873
# r2_20_2_Higuchi = 0.956674933951199  	 MSE = 285.2402262938667
# r2_20_3_Higuchi = 0.9868000445998222  	 MSE = 94.11719868024684
# r2_20_4_Higuchi = 0.9657915929148463  	 MSE = 223.30480112931457
# ...
# MEDIA_R2= 0.9588341731782817
# SD_R2= 0.02522327672828801
# MEDIA_MSE= 292.1148931943039
# SD_MSE= 199.0705588398376

# %% [markdown]
# #### HCl 30%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.higuchi, x, y_30_1)
parametros_2, covarianza_2 = curve_fit(modelos.higuchi, x, y_30_2)
parametros_3, covarianza_3 = curve_fit(modelos.higuchi, x, y_30_3)
parametros_4, covarianza_4 = curve_fit(modelos.higuchi, x, y_30_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_30_1 = np.array(modelos.higuchi(x, coef_123[0], coef_123[1]))
y_30_4 = np.array(y_30_4)
ax.plot(x, y_30_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_30_4, '-', label='Medida 1 fit', color='b')
r2_30_4 = r2_score(y_30_4, y_pred_30_4)
mse_4 = mean_squared_error(y_30_4, y_pred_30_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_30_3 = np.array(modelos.higuchi(x, coef_124[0], coef_124[1]))
y_30_3 = np.array(y_30_3)
ax.plot(x, y_30_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_30_3, '-', label='Medida 2 fit', color='g')
r2_30_3 = r2_score(y_30_3, y_pred_30_3)
mse_3 = mean_squared_error(y_30_3, y_pred_30_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_30_2 = np.array(modelos.higuchi(x, coef_134[0], coef_134[1]))
y_30_2 = np.array(y_30_2)
ax.plot(x, y_30_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_30_2, '-', label='Medida 3 fit', color='r')
r2_30_2 = r2_score(y_30_2, y_pred_30_2)
mse_2 = mean_squared_error(y_30_2, y_pred_30_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_30_1 = np.array(modelos.higuchi(x, coef_234[0], coef_234[1]))
y_30_1 = np.array(y_30_1)
ax.plot(x, y_30_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_30_1, '-', label='Medida 4 fit', color='y')
r2_30_1 = r2_score(y_30_1, y_pred_30_1)
mse_1 = mean_squared_error(y_30_1, y_pred_30_1)
print(coef_234[0], coef_234[1])
# Out:
# 16.103901937002224 -50.995596506751404
# 15.57955566484072 -49.38366373512966
# 15.753095586762234 -48.22784595219155
# 15.974652083298983 -50.7345920120137

# %%
print('======================== R2 SCORE HIGUCHI ========================')
print('r2_30_1_Higuchi =', r2_30_1, ' \t MSE =', mse_1)
print('r2_30_2_Higuchi =', r2_30_2, ' \t MSE =', mse_2)
print('r2_30_3_Higuchi =', r2_30_3, ' \t MSE =', mse_3)
print('r2_30_4_Higuchi =', r2_30_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_30_1, r2_30_2, r2_30_3, r2_30_4]))
print('SD_R2=', statistics.stdev([r2_30_1, r2_30_2, r2_30_3, r2_30_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE HIGUCHI ========================
# r2_30_1_Higuchi = 0.9711734769600437  	 MSE = 144.2359442076992
# r2_30_2_Higuchi = 0.9636239460229976  	 MSE = 199.46793554277863
# r2_30_3_Higuchi = 0.9555119610841195  	 MSE = 257.3387169467995
# r2_30_4_Higuchi = 0.9760677505595736  	 MSE = 114.01823737998609
# ...
# MEDIA_R2= 0.9665942836566837
# SD_R2= 0.008988072943817376
# MEDIA_MSE= 178.76520851931585
# SD_MSE= 63.210862722664324

# %% [markdown]
# #### HCl 40%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.higuchi, x, y_40_1)
parametros_2, covarianza_2 = curve_fit(modelos.higuchi, x, y_40_2)
parametros_3, covarianza_3 = curve_fit(modelos.higuchi, x, y_40_3)
parametros_4, covarianza_4 = curve_fit(modelos.higuchi, x, y_40_4)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_40_4 = np.array(modelos.higuchi(x, coef_123[0], coef_123[1]))
y_40_4 = np.array(y_40_4)
ax.plot(x, y_40_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_40_4, '-', label='Medida 1 fit', color='b')
r2_40_4 = r2_score(y_40_4, y_pred_40_4)
mse_4 = mean_squared_error(y_40_4, y_pred_40_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_40_3 = np.array(modelos.higuchi(x, coef_124[0], coef_124[1]))
y_40_3 = np.array(y_40_3)
ax.plot(x, y_40_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_40_3, '-', label='Medida 2 fit', color='g')
r2_40_3 = r2_score(y_40_3, y_pred_40_3)
mse_3 = mean_squared_error(y_40_3, y_pred_40_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_40_2 = np.array(modelos.higuchi(x, coef_134[0], coef_134[1]))
y_40_2 = np.array(y_40_2)
ax.plot(x, y_40_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_40_2, '-', label='Medida 3 fit', color='r')
r2_40_2 = r2_score(y_40_2, y_pred_40_2)
mse_2 = mean_squared_error(y_40_2, y_pred_40_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_40_1 = np.array(modelos.higuchi(x, coef_234[0], coef_234[1]))
y_40_1 = np.array(y_40_1)
ax.plot(x, y_40_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_40_1, '-', label='Medida 4 fit', color='y')
r2_40_1 = r2_score(y_40_1, y_pred_40_1)
mse_1 = mean_squared_error(y_40_1, y_pred_40_1)
print(coef_234[0], coef_234[1])
# Out:
# 13.342977668760566 -47.46886763980916
# 13.454398221692978 -47.541083652799784
# 13.379693752650303 -45.14943664152668
# 13.511464780630055 -47.7795475847639

# %%
print('====================== R2 SCORE HIGUCHI ======================')
print('r2_40_1_Higuchi =', r2_40_1, ' \t MSE =', mse_1)
print('r2_40_2_Higuchi =', r2_40_2, ' \t MSE =', mse_2)
print('r2_40_3_Higuchi =', r2_40_3, ' \t MSE =', mse_3)
print('r2_40_4_Higuchi =', r2_40_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_40_1, r2_40_2, r2_40_3, r2_40_4]))
print('SD_R2=', statistics.stdev([r2_40_1, r2_40_2, r2_40_3, r2_40_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE HIGUCHI ======================
# r2_40_1_Higuchi = 0.96231234326423  	 MSE = 137.37022437086642
# r2_40_2_Higuchi = 0.9358661350673901  	 MSE = 253.05018854302597
# r2_40_3_Higuchi = 0.9634388838401426  	 MSE = 136.6615698008795
# r2_40_4_Higuchi = 0.9575507057752497  	 MSE = 166.5309295202338
# ...
# MEDIA_R2= 0.9547920169867531
# SD_R2= 0.012872748786453277
# MEDIA_MSE= 173.40322805875144
# SD_MSE= 54.89138854105588

# %% [markdown]
# # Tanh

# %% [markdown]
# #### HCl 1%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.tanh, x, y_01_1, maxfev=5000)
parametros_2, covarianza_2 = curve_fit(modelos.tanh, x, y_01_2, maxfev=5000)
parametros_3, covarianza_3 = curve_fit(modelos.tanh, x, y_01_3, maxfev=5000)
parametros_4, covarianza_4 = curve_fit(modelos.tanh, x, y_01_4, maxfev=5000)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_01_4 = np.array(modelos.tanh(x, coef_123[0], coef_123[1]))
y_01_4 = np.array(y_01_4)
ax.plot(x, y_01_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_01_4, '-', label='Medida 1 fit', color='b')
r2_01_4 = r2_score(y_01_4, y_pred_01_4)
mse_4 = mean_squared_error(y_01_4, y_pred_01_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_01_3 = np.array(modelos.tanh(x, coef_124[0], coef_124[1]))
y_01_3 = np.array(y_01_3)
ax.plot(x, y_01_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_01_3, '-', label='Medida 2 fit', color='g')
r2_01_3 = r2_score(y_01_3, y_pred_01_3)
mse_3 = mean_squared_error(y_01_3, y_pred_01_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_01_2 = np.array(modelos.tanh(x, coef_134[0], coef_134[1]))
y_01_2 = np.array(y_01_2)
ax.plot(x, y_01_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_01_2, '-', label='Medida 3 fit', color='r')
r2_01_2 = r2_score(y_01_2, y_pred_01_2)
mse_2 = mean_squared_error(y_01_2, y_pred_01_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_01_1 = np.array(modelos.tanh(x, coef_234[0], coef_234[1]))
y_01_1 = np.array(y_01_1)
ax.plot(x, y_01_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_01_1, '-', label='Medida 4 fit', color='y')
r2_01_1 = r2_score(y_01_1, y_pred_01_1)
mse_1 = mean_squared_error(y_01_1, y_pred_01_4)
print(coef_234[0], coef_234[1])

ax.legend()
plt.show()
# Out:
# 228967.97665349251 9.36129067835354e-05
# 224318.61675513608 9.41014379620243e-05
# 227474.1725215489 9.361611667171956e-05
# 221774.0685825403 9.388154074807059e-05

# %%
print('======================== R2 SCORE TANH ========================')
print('r2_01_1_Tanh =', r2_01_1, ' \t MSE =', mse_1)
print('r2_01_2_Tanh =', r2_01_2, ' \t MSE =', mse_2)
print('r2_01_3_Tanh =', r2_01_3, ' \t MSE =', mse_3)
print('r2_01_4_Tanh =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('SD_R2=', statistics.stdev([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE TANH ========================
# r2_01_1_Tanh = 0.9558481051513179  	 MSE = 428.06601408275145
# r2_01_2_Tanh = 0.9618706236768088  	 MSE = 470.87042599640006
# r2_01_3_Tanh = 0.9723331131829892  	 MSE = 344.22867267991137
# r2_01_4_Tanh = 0.9606782464051868  	 MSE = 440.39770928724187
# ...
# MEDIA_R2= 0.9626825221040757
# SD_R2= 0.0069406883277742
# MEDIA_MSE= 420.8907055115762
# SD_MSE= 54.1819403707539

# %% [markdown]
# #### HCl 5%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.tanh, x, y_05_1, maxfev=5000)
parametros_2, covarianza_2 = curve_fit(modelos.tanh, x, y_05_2, maxfev=5000)
parametros_3, covarianza_3 = curve_fit(modelos.tanh, x, y_05_3, maxfev=5000)
parametros_4, covarianza_4 = curve_fit(modelos.tanh, x, y_05_4, maxfev=5000)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_05_4 = np.array(modelos.tanh(x, coef_123[0], coef_123[1]))
y_05_4 = np.array(y_05_4)
ax.plot(x, y_05_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_05_4, '-', label='Medida 1 fit', color='b')
r2_05_4 = r2_score(y_05_4, y_pred_05_4)
mse_4 = mean_squared_error(y_05_4, y_pred_05_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_05_3 = np.array(modelos.tanh(x, coef_124[0], coef_124[1]))
y_05_3 = np.array(y_05_3)
ax.plot(x, y_05_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_05_3, '-', label='Medida 2 fit', color='g')
r2_05_3 = r2_score(y_05_3, y_pred_05_3)
mse_3 = mean_squared_error(y_05_3, y_pred_05_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_05_2 = np.array(modelos.tanh(x, coef_134[0], coef_134[1]))
y_05_2 = np.array(y_05_2)
ax.plot(x, y_05_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_05_2, '-', label='Medida 3 fit', color='r')
r2_05_2 = r2_score(y_05_2, y_pred_05_2)
mse_2 = mean_squared_error(y_05_2, y_pred_05_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_05_1 = np.array(modelos.tanh(x, coef_234[0], coef_234[1]))
y_05_1 = np.array(y_05_1)
ax.plot(x, y_05_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_05_1, '-', label='Medida 4 fit', color='y')
r2_05_1 = r2_score(y_05_1, y_pred_05_1)
mse_1 = mean_squared_error(y_05_1, y_pred_05_1)
print(coef_234[0], coef_234[1])

ax.legend()
plt.show()
# Out:
# 200126.27876121053 9.873108932352134e-05
# 201091.62943685733 9.721792449438089e-05
# 200003.6478005794 9.761920671154068e-05
# 194654.29543084372 9.875785805423734e-05

# %%
print('======================== R2 SCORE TANH ========================')
print('r2_05_1_Tanh =', r2_05_1, ' \t MSE =', mse_1)
print('r2_05_2_Tanh =', r2_05_2, ' \t MSE =', mse_2)
print('r2_05_3_Tanh =', r2_05_3, ' \t MSE =', mse_3)
print('r2_05_4_Tanh =', r2_05_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_05_1, r2_05_2, r2_05_3, r2_05_4]))
print('SD_R2=', statistics.stdev([r2_05_1, r2_05_2, r2_05_3, r2_05_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE TANH ========================
# r2_05_1_Tanh = 0.944242344055033  	 MSE = 688.6757761276028
# r2_05_2_Tanh = 0.9643810239549618  	 MSE = 387.34482565921934
# r2_05_3_Tanh = 0.958983261898543  	 MSE = 452.4993224916572
# r2_05_4_Tanh = 0.9564181037678889  	 MSE = 431.1438016074272
# ...
# MEDIA_R2= 0.9560061834191067
# SD_R2= 0.008515839070641538
# MEDIA_MSE= 489.91593147147665
# SD_MSE= 135.2534330699004

# %% [markdown]
# #### HCl 10%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.tanh, x, y_10_1, maxfev=5000)
parametros_2, covarianza_2 = curve_fit(modelos.tanh, x, y_10_2, maxfev=5000)
parametros_3, covarianza_3 = curve_fit(modelos.tanh, x, y_10_3, maxfev=5000)
parametros_4, covarianza_4 = curve_fit(modelos.tanh, x, y_10_4, maxfev=5000)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_10_4 = np.array(modelos.tanh(x, coef_123[0], coef_123[1]))
y_10_4 = np.array(y_10_4)
ax.plot(x, y_10_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_10_4, '-', label='Medida 1 fit', color='b')
r2_10_4 = r2_score(y_10_4, y_pred_10_4)
mse_4 = mean_squared_error(y_10_4, y_pred_10_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_10_3 = np.array(modelos.tanh(x, coef_124[0], coef_124[1]))
y_10_3 = np.array(y_10_3)
ax.plot(x, y_10_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_10_3, '-', label='Medida 2 fit', color='g')
r2_10_3 = r2_score(y_10_3, y_pred_10_3)
mse_3 = mean_squared_error(y_10_3, y_pred_10_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_10_2 = np.array(modelos.tanh(x, coef_134[0], coef_134[1]))
y_10_2 = np.array(y_10_2)
ax.plot(x, y_10_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_10_2, '-', label='Medida 3 fit', color='r')
r2_10_2 = r2_score(y_10_2, y_pred_10_2)
mse_2 = mean_squared_error(y_10_2, y_pred_10_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_10_1 = np.array(modelos.tanh(x, coef_234[0], coef_234[1]))
y_10_1 = np.array(y_10_1)
ax.plot(x, y_10_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_10_1, '-', label='Medida 4 fit', color='y')
r2_10_1 = r2_score(y_10_1, y_pred_10_1)
mse_1 = mean_squared_error(y_10_1, y_pred_10_1)
print(coef_234[0], coef_234[1])

ax.legend()
plt.show()
# Out:
# 177560.73010180975 0.00010159084340080962
# 178987.13044343668 0.00010024000140065436
# 178598.01371983552 0.00010230327953707761
# 177106.22295165018 0.00010050260061292609

# %%
print('======================== R2 SCORE TANH ========================')
print('r2_10_1_Tanh =', r2_10_1, ' \t MSE =', mse_1)
print('r2_10_2_Tanh =', r2_10_2, ' \t MSE =', mse_2)
print('r2_10_3_Tanh =', r2_10_3, ' \t MSE =', mse_3)
print('r2_10_4_Tanh =', r2_10_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_10_1, r2_10_2, r2_10_3, r2_10_4]))
print('SD_R2=', statistics.stdev([r2_10_1, r2_10_2, r2_10_3, r2_10_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE TANH ========================
# r2_10_1_Tanh = 0.9546440475157243  	 MSE = 450.4538749611268
# r2_10_2_Tanh = 0.9389295706166989  	 MSE = 549.3017313028932
# r2_10_3_Tanh = 0.9711278472807705  	 MSE = 259.51861025212486
# r2_10_4_Tanh = 0.9685825788013156  	 MSE = 281.3389576869007
# ...
# MEDIA_R2= 0.9583210110536273
# SD_R2= 0.014819613691178258
# MEDIA_MSE= 385.1532935507614
# SD_MSE= 138.76883118745894

# %% [markdown]
# #### HCl 20%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.tanh, x, y_20_1, maxfev=5000)
parametros_2, covarianza_2 = curve_fit(modelos.tanh, x, y_20_2, maxfev=5000)
parametros_3, covarianza_3 = curve_fit(modelos.tanh, x, y_20_3, maxfev=5000)
parametros_4, covarianza_4 = curve_fit(modelos.tanh, x, y_20_4, maxfev=5000)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_20_4 = np.array(modelos.tanh(x, coef_123[0], coef_123[1]))
y_20_4 = np.array(y_20_4)
ax.plot(x, y_20_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_20_4, '-', label='Medida 1 fit', color='b')
r2_20_4 = r2_score(y_20_4, y_pred_20_4)
mse_4 = mean_squared_error(y_20_4, y_pred_20_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_20_3 = np.array(modelos.tanh(x, coef_124[0], coef_124[1]))
y_20_3 = np.array(y_20_3)
ax.plot(x, y_20_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_20_3, '-', label='Medida 2 fit', color='g')
r2_20_3 = r2_score(y_20_3, y_pred_20_3)
mse_3 = mean_squared_error(y_20_3, y_pred_20_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_20_2 = np.array(modelos.tanh(x, coef_134[0], coef_134[1]))
y_20_2 = np.array(y_20_2)
ax.plot(x, y_20_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_20_2, '-', label='Medida 3 fit', color='r')
r2_20_2 = r2_score(y_20_2, y_pred_20_2)
mse_2 = mean_squared_error(y_20_2, y_pred_20_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_20_1 = np.array(modelos.tanh(x, coef_234[0], coef_234[1]))
y_20_1 = np.array(y_20_1)
ax.plot(x, y_20_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_20_1, '-', label='Medida 4 fit', color='y')
r2_20_1 = r2_score(y_20_1, y_pred_20_1)
mse_1 = mean_squared_error(y_20_1, y_pred_20_1)
print(coef_234[0], coef_234[1])

ax.legend()
plt.show()
# Out:
# 148646.74881772118 9.962009500321738e-05
# 144410.3075389956 0.00010065748187281648
# 147988.33097694453 0.00010048148317593604
# 139886.40893840467 0.000100693787982316

# %%
print('======================== R2 SCORE TANH ========================')
print('r2_20_1_Tanh =', r2_20_1, ' \t MSE =', mse_1)
print('r2_20_2_Tanh =', r2_20_2, ' \t MSE =', mse_2)
print('r2_20_3_Tanh =', r2_20_3, ' \t MSE =', mse_3)
print('r2_20_4_Tanh =', r2_20_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_20_1, r2_20_2, r2_20_3, r2_20_4]))
print('SD_R2=', statistics.stdev([r2_20_1, r2_20_2, r2_20_3, r2_20_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE TANH ========================
# r2_20_1_Tanh = 0.8936897117996  	 MSE = 813.6098692801112
# r2_20_2_Tanh = 0.8930704010950639  	 MSE = 703.9948411111648
# r2_20_3_Tanh = 0.9343549326504912  	 MSE = 468.0568728306982
# r2_20_4_Tanh = 0.908223475703625  	 MSE = 599.0965453412213
# ...
# MEDIA_R2= 0.907334630312195
# SD_R2= 0.019326482875034596
# MEDIA_MSE= 646.1895321407989
# SD_MSE= 147.55791716203512

# %% [markdown]
# #### HCl 30%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.tanh, x, y_30_1, maxfev=5000)
parametros_2, covarianza_2 = curve_fit(modelos.tanh, x, y_30_2, maxfev=5000)
parametros_3, covarianza_3 = curve_fit(modelos.tanh, x, y_30_3, maxfev=5000)
parametros_4, covarianza_4 = curve_fit(modelos.tanh, x, y_30_4, maxfev=5000)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_30_4 = np.array(modelos.tanh(x, coef_123[0], coef_123[1]))
y_30_4 = np.array(y_30_4)
ax.plot(x, y_30_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_30_4, '-', label='Medida 1 fit', color='b')
r2_30_4 = r2_score(y_30_4, y_pred_30_4)
mse_4 = mean_squared_error(y_30_4, y_pred_30_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_30_3 = np.array(modelos.tanh(x, coef_124[0], coef_124[1]))
y_30_3 = np.array(y_30_3)
ax.plot(x, y_30_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_30_3, '-', label='Medida 2 fit', color='g')
r2_30_3 = r2_score(y_30_3, y_pred_30_3)
mse_3 = mean_squared_error(y_30_3, y_pred_30_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_30_2 = np.array(modelos.tanh(x, coef_134[0], coef_134[1]))
y_30_2 = np.array(y_30_2)
ax.plot(x, y_30_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_30_2, '-', label='Medida 3 fit', color='r')
r2_30_2 = r2_score(y_30_2, y_pred_30_2)
mse_2 = mean_squared_error(y_30_2, y_pred_30_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_30_1 = np.array(modelos.tanh(x, coef_234[0], coef_234[1]))
y_30_1 = np.array(y_30_1)
ax.plot(x, y_30_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_30_1, '-', label='Medida 4 fit', color='y')
r2_30_1 = r2_score(y_30_1, y_pred_30_1)
mse_1 = mean_squared_error(y_30_1, y_pred_30_1)
print(coef_234[0], coef_234[1])

ax.legend()
plt.show()
# Out:
# 114299.01308506231 0.00010439215865289287
# 110636.69722144316 0.00010429745447059489
# 113475.82799607841 0.0001040439775783754
# 113133.38686639174 0.00010451173564858514

# %%
print('======================== R2 SCORE TANH ========================')
print('r2_30_1_Tanh =', r2_30_1, ' \t MSE =', mse_1)
print('r2_30_2_Tanh =', r2_30_2, ' \t MSE =', mse_2)
print('r2_30_3_Tanh =', r2_30_3, ' \t MSE =', mse_3)
print('r2_30_4_Tanh =', r2_30_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_30_1, r2_30_2, r2_30_3, r2_30_4]))
print('SD_R2=', statistics.stdev([r2_30_1, r2_30_2, r2_30_3, r2_30_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE TANH ========================
# r2_30_1_Tanh = 0.8996186569809558  	 MSE = 502.2665331895928
# r2_30_2_Tanh = 0.8765497674793234  	 MSE = 676.9388191127968
# r2_30_3_Tanh = 0.8821790539862748  	 MSE = 681.5290539994376
# r2_30_4_Tanh = 0.8875223010587749  	 MSE = 535.8672618618135
# ...
# MEDIA_R2= 0.8864674448763322
# SD_R2= 0.00984577274372951
# MEDIA_MSE= 599.1504170409102
# SD_MSE= 93.50315503336331

# %% [markdown]
# #### HCl 40%

# %%
fig, ax = plt.subplots()
parametros_1, covarianza_1 = curve_fit(modelos.tanh, x, y_40_1, maxfev=5000)
parametros_2, covarianza_2 = curve_fit(modelos.tanh, x, y_40_2, maxfev=5000)
parametros_3, covarianza_3 = curve_fit(modelos.tanh, x, y_40_3, maxfev=5000)
parametros_4, covarianza_4 = curve_fit(modelos.tanh, x, y_40_4, maxfev=5000)
x=np.array(x)

# Entrenamiento: 1, 2 y 3. Evaluación: 4
coef_123 = []
coef_123.append((parametros_1[0]+parametros_2[0]+parametros_3[0])/3)
coef_123.append((parametros_1[1]+parametros_2[1]+parametros_3[1])/3)
y_pred_40_4 = np.array(modelos.tanh(x, coef_123[0], coef_123[1]))
y_40_4 = np.array(y_40_4)
ax.plot(x, y_40_4, 'o', label='Medida 1 data', color='b')
ax.plot(x, y_pred_40_4, '-', label='Medida 1 fit', color='b')
r2_40_4 = r2_score(y_40_4, y_pred_40_4)
mse_4 = mean_squared_error(y_40_4, y_pred_40_4)
print(coef_123[0], coef_123[1])

# Entrenamiento: 1, 2 y 4. Evaluación: 3
coef_124 = []
coef_124.append((parametros_1[0]+parametros_2[0]+parametros_4[0])/3)
coef_124.append((parametros_1[1]+parametros_2[1]+parametros_4[1])/3)
y_pred_40_3 = np.array(modelos.tanh(x, coef_124[0], coef_124[1]))
y_40_3 = np.array(y_40_3)
ax.plot(x, y_40_3, 'o', label='Medida 2 data', color='g')
ax.plot(x, y_pred_40_3, '-', label='Medida 2 fit', color='g')
r2_40_3 = r2_score(y_40_3, y_pred_40_3)
mse_3 = mean_squared_error(y_40_3, y_pred_40_3)
print(coef_124[0], coef_124[1])

# Entrenamiento: 1, 3 y 4. Evaluación: 2
coef_134 = []
coef_134.append((parametros_1[0]+parametros_3[0]+parametros_4[0])/3)
coef_134.append((parametros_1[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_40_2 = np.array(modelos.tanh(x, coef_134[0], coef_134[1]))
y_40_2 = np.array(y_40_2)
ax.plot(x, y_40_2, 'o', label='Medida 3 data', color='r')
ax.plot(x, y_pred_40_2, '-', label='Medida 3 fit', color='r')
r2_40_2 = r2_score(y_40_2, y_pred_40_2)
mse_2 = mean_squared_error(y_40_2, y_pred_40_2)
print(coef_134[0], coef_134[1])

# Entrenamiento: 2, 3 y 4. Evaluación: 1
coef_234 = []
coef_234.append((parametros_2[0]+parametros_3[0]+parametros_4[0])/3)
coef_234.append((parametros_2[1]+parametros_3[1]+parametros_4[1])/3)
y_pred_40_1 = np.array(modelos.tanh(x, coef_234[0], coef_234[1]))
y_40_1 = np.array(y_40_1)
ax.plot(x, y_40_1, 'o', label='Medida 4 data', color='y')
ax.plot(x, y_pred_40_1, '-', label='Medida 4 fit', color='y')
r2_40_1 = r2_score(y_40_1, y_pred_40_1)
mse_1 = mean_squared_error(y_40_1, y_pred_40_1)
print(coef_234[0], coef_234[1])

ax.legend()
plt.show()
# Out:
# 89217.40650334289 0.00010607899553136439
# 90421.6551600233 0.00010585494818315511
# 92456.35591237964 0.00010476107734996546
# 90519.17536196439 0.00010615463795377263

# %%
print('======================== R2 SCORE TANH ========================')
print('r2_40_1_Tanh =', r2_40_1, ' \t MSE =', mse_1)
print('r2_40_2_Tanh =', r2_40_2, ' \t MSE =', mse_2)
print('r2_40_3_Tanh =', r2_40_3, ' \t MSE =', mse_3)
print('r2_40_4_Tanh =', r2_40_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_40_1, r2_40_2, r2_40_3, r2_40_4]))
print('SD_R2=', statistics.stdev([r2_40_1, r2_40_2, r2_40_3, r2_40_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ======================== R2 SCORE TANH ========================
# r2_40_1_Tanh = 0.874266030566338  	 MSE = 458.2960334530048
# r2_40_2_Tanh = 0.8249004627238383  	 MSE = 690.8825932771709
# r2_40_3_Tanh = 0.8746368234011938  	 MSE = 468.59424188007523
# r2_40_4_Tanh = 0.8722019067480895  	 MSE = 501.3589895623135
# ...
# MEDIA_R2= 0.8615013058598648
# SD_R2= 0.024424063240635587
# MEDIA_MSE= 529.7829645431411
# SD_MSE= 108.9578723326535

# %% [markdown]
# ### KORSMEYER-PEPPAS

# %%
y_01_1_ult = y_01_1[-1]*0.6
fil_01_1 = fil_01[fil_01['Medida 1']<=y_01_1_ult]
y_01_2_ult = y_01_2[-1]*0.6
fil_01_2 = fil_01[fil_01['Medida 2']<=y_01_2_ult]
y_01_3_ult = y_01_3[-1]*0.6
fil_01_3 = fil_01[fil_01['Medida 3']<=y_01_3_ult]
y_01_4_ult = y_01_4[-1]*0.6
fil_01_4 = fil_01[fil_01['Medida 4']<=y_01_4_ult]

y_05_1_ult = y_05_1[-1]*0.6
fil_05_1 = fil_05[fil_05['Medida 1']<=y_05_1_ult]
y_05_2_ult = y_05_2[-1]*0.6
fil_05_2 = fil_05[fil_05['Medida 2']<=y_05_2_ult]
y_05_3_ult = y_05_3[-1]*0.6
fil_05_3 = fil_05[fil_05['Medida 3']<=y_05_3_ult]
y_05_4_ult = y_05_4[-1]*0.6
fil_05_4 = fil_05[fil_05['Medida 4']<=y_05_3_ult]

y_10_1_ult = y_10_1[-1]*0.6
fil_10_1 = fil_10[fil_10['Medida 1']<=y_10_1_ult]
y_10_2_ult = y_10_2[-1]*0.6
fil_10_2 = fil_10[fil_10['Medida 2']<=y_10_2_ult]
y_10_3_ult = y_10_3[-1]*0.6
fil_10_3 = fil_10[fil_10['Medida 3']<=y_10_3_ult]
y_10_4_ult = y_10_4[-1]*0.6
fil_10_4 = fil_10[fil_10['Medida 4']<=y_10_4_ult]

y_20_1_ult = y_20_1[-1]*0.6
fil_20_1 = fil_20[fil_20['Medida 1']<=y_20_1_ult]
y_20_2_ult = y_20_2[-1]*0.6
fil_20_2 = fil_20[fil_20['Medida 2']<=y_20_2_ult]
y_20_3_ult = y_20_3[-1]*0.6
fil_20_3 = fil_20[fil_20['Medida 3']<=y_20_3_ult]
y_20_4_ult = y_20_4[-1]*0.6
fil_20_4 = fil_20[fil_20['Medida 4']<=y_20_4_ult]

y_30_1_ult = y_30_1[-1]*0.6
fil_30_1 = fil_30[fil_30['Medida 1']<=y_30_1_ult]
y_30_2_ult = y_30_2[-1]*0.6
fil_30_2 = fil_30[fil_30['Medida 2']<=y_30_2_ult]
y_30_3_ult = y_30_3[-1]*0.6
fil_30_3 = fil_30[fil_30['Medida 3']<=y_30_3_ult]
y_30_4_ult = y_30_4[-1]*0.6
fil_30_4 = fil_30[fil_30['Medida 4']<=y_30_4_ult]

y_40_1_ult = y_40_1[-1]*0.6
fil_40_1 = fil_40[fil_40['Medida 1']<=y_40_1_ult]
y_40_2_ult = y_40_2[-1]*0.6
fil_40_2 = fil_40[fil_40['Medida 2']<=y_40_2_ult]
y_40_3_ult = y_40_3[-1]*0.6
fil_40_3 = fil_40[fil_40['Medida 3']<=y_40_3_ult]
y_40_4_ult = y_40_4[-1]*0.6
fil_40_4 = fil_40[fil_40['Medida 4']<=y_40_4_ult]


y_01_1_b = fil_01_1['Medida 1'].values.tolist()
x_01_1 = fil_01_1['Hora'].values.tolist()
y_01_2_b = fil_01_2['Medida 2'].values.tolist()
x_01_2 = fil_01_2['Hora'].values.tolist()
y_01_3_b = fil_01_3['Medida 3'].values.tolist()
x_01_3 = fil_01_3['Hora'].values.tolist()
y_01_4_b = fil_01_4['Medida 4'].values.tolist()
x_01_4 = fil_01_4['Hora'].values.tolist()

y_05_1_b = fil_05_1['Medida 1'].values.tolist()
x_05_1 = fil_05_1['Hora'].values.tolist()
y_05_2_b = fil_05_2['Medida 2'].values.tolist()
x_05_2 = fil_05_2['Hora'].values.tolist()
y_05_3_b = fil_05_3['Medida 3'].values.tolist()
x_05_3 = fil_05_3['Hora'].values.tolist()
y_05_4_b = fil_05_4['Medida 4'].values.tolist()
x_05_4 = fil_05_4['Hora'].values.tolist()

y_10_1_b = fil_10_1['Medida 1'].values.tolist()
x_10_1 = fil_10_1['Hora'].values.tolist()
y_10_2_b = fil_10_2['Medida 2'].values.tolist()
x_10_2 = fil_10_2['Hora'].values.tolist()
y_10_3_b = fil_10_3['Medida 3'].values.tolist()
x_10_3 = fil_10_3['Hora'].values.tolist()
y_10_4_b = fil_10_4['Medida 4'].values.tolist()
x_10_4 = fil_10_4['Hora'].values.tolist()

y_20_1_b = fil_20_1['Medida 1'].values.tolist()
x_20_1 = fil_20_1['Hora'].values.tolist()
y_20_2_b = fil_20_2['Medida 2'].values.tolist()
x_20_2 = fil_20_2['Hora'].values.tolist()
y_20_3_b = fil_20_3['Medida 3'].values.tolist()
x_20_3 = fil_20_3['Hora'].values.tolist()
y_20_4_b = fil_20_4['Medida 4'].values.tolist()
x_20_4 = fil_20_4['Hora'].values.tolist()

y_30_1_b = fil_30_1['Medida 1'].values.tolist()
x_30_1 = fil_30_1['Hora'].values.tolist()
y_30_2_b = fil_30_2['Medida 2'].values.tolist()
x_30_2 = fil_30_2['Hora'].values.tolist()
y_30_3_b = fil_30_3['Medida 3'].values.tolist()
x_30_3 = fil_30_3['Hora'].values.tolist()
y_30_4_b = fil_30_4['Medida 4'].values.tolist()
x_30_4 = fil_30_4['Hora'].values.tolist()

y_40_1_b = fil_40_1['Medida 1'].values.tolist()
x_40_1 = fil_40_1['Hora'].values.tolist()
y_40_2_b = fil_40_2['Medida 2'].values.tolist()
x_40_2 = fil_40_2['Hora'].values.tolist()
y_40_3_b = fil_40_3['Medida 3'].values.tolist()
x_40_3 = fil_40_3['Hora'].values.tolist()
y_40_4_b = fil_40_4['Medida 4'].values.tolist()
x_40_4 = fil_40_4['Hora'].values.tolist()

# %% [markdown]
# #### HCl 1%

# %%
fig, ax = plt.subplots()

M_01_1_equi = y_01_1_b/y_01_1[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_01_1, M_01_1_equi)
n_01_1 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_01_1, parametros[0], n_01_1))
ax.plot(x_01_1, M_01_1_equi, 'o', label='Medida 1 data', color='b')
ax.plot(x_01_1, fit_y, '-', label='Medida 1 fit', color='b')
r2_kors_01_1 = r2_score(M_01_1_equi, fit_y)
mse_1 = mean_squared_error(M_01_1_equi, fit_y)
print(parametros[0], parametros[1])

M_01_2_equi = y_01_2_b/y_01_2[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_01_2, M_01_2_equi)
n_01_2 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_01_2, parametros[0], n_01_2))
ax.plot(x_01_2, M_01_2_equi, 'o', label='Medida 2 data', color='g')
ax.plot(x_01_2, fit_y, '-', label='Medida 2 fit', color='g')
r2_kors_01_2 = r2_score(M_01_2_equi, fit_y)
mse_2 = mean_squared_error(M_01_2_equi, fit_y)
print(parametros[0], parametros[1])

M_01_3_equi = y_01_3_b/y_01_3[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_01_3, M_01_3_equi)
n_01_3 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_01_3, parametros[0], n_01_3))
ax.plot(x_01_3, M_01_3_equi, 'o', label='Medida 3 data', color='r')
ax.plot(x_01_3, fit_y, '-', label='Medida 3 fit', color='r')
r2_kors_01_3 = r2_score(M_01_3_equi, fit_y)
mse_3 = mean_squared_error(M_01_3_equi, fit_y)
print(parametros[0], parametros[1])

M_01_4_equi = y_01_4_b/y_01_4[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_01_4, M_01_4_equi)
n_01_4 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_01_4, parametros[0], n_01_4))
ax.plot(x_01_4, M_01_4_equi, 'o', label='Medida 4 data', color='y')
ax.plot(x_01_4, fit_y, '-', label='Medida 4 fit', color='y')
r2_kors_01_4 = r2_score(M_01_4_equi, fit_y)
mse_4 = mean_squared_error(M_01_4_equi, fit_y)
print(parametros[0], parametros[1])

ax.legend()
plt.show()

# %%
print('========================== R2 SCORE KORSMEYER-PEPPAS ==========================')
print('r2_01_1_Korsmeyer-Peppas =', r2_kors_01_1, " \t MSE = ", mse_1)
print('r2_01_2_Korsmeyer-Peppas =', r2_kors_01_2, " \t MSE = ", mse_2)
print('r2_01_3_Korsmeyer-Peppas =', r2_kors_01_3, " \t MSE = ", mse_3)
print('r2_01_4_Korsmeyer-Peppas =', r2_kors_01_4, " \t MSE = ", mse_4)
print('===============================================================================')
print('')
print('======== VALORES PARA n =======')
print('n_01_1 =', n_01_1)
print('n_01_2 =', n_01_2)
print('n_01_3 =', n_01_3)
print('n_01_4 =', n_01_4)
print('===============================')

print('=== Shapiro-Wilk ===')
print('H0: datos normales')
print('H1: datos no normales')
x = np.array([r2_kors_01_1,r2_kors_01_2,r2_kors_01_3,r2_kors_01_4])
res = stats.shapiro(x)
print('p-valor =', res.pvalue)
print('=== T-Student ===')
print('H0: La media es igual a 1')
print('H1: La media NO es igual a 1')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='less')
print('p-valor =', t_student)
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='greater')
print('p-valor =', t_student)

# %% [markdown]
# #### HCl 5%

# %%
fig, ax = plt.subplots()

M_05_1_equi = y_05_1_b/y_05_1[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_05_1, M_05_1_equi)
n_05_1 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_05_1, parametros[0], n_05_1))
ax.plot(x_05_1, M_05_1_equi, 'o', label='Medida 1 data', color='b')
ax.plot(x_05_1, fit_y, '-', label='Medida 1 fit', color='b')
r2_kors_05_1 = r2_score(M_05_1_equi, fit_y)
mse_1 = mean_squared_error(M_05_1_equi, fit_y)
print(parametros[0], parametros[1])

M_05_2_equi = y_05_2_b/y_05_2[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_05_2, M_05_2_equi)
n_05_2 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_05_2, parametros[0], n_05_2))
y_05_2 = np.array(y_05_2)
ax.plot(x_05_2, M_05_2_equi, 'o', label='Medida 2 data', color='g')
ax.plot(x_05_2, fit_y, '-', label='Medida 2 fit', color='g')
r2_kors_05_2 = r2_score(M_05_2_equi, fit_y)
mse_2 = mean_squared_error(M_05_2_equi, fit_y)
print(parametros[0], parametros[1])

M_05_3_equi = y_05_3_b/y_05_3[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_05_3, M_05_3_equi)
n_05_3 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_05_3, parametros[0], n_05_3))
ax.plot(x_05_3, M_05_3_equi, 'o', label='Medida 3 data', color='r')
ax.plot(x_05_3, fit_y, '-', label='Medida 3 fit', color='r')
r2_kors_05_3 = r2_score(M_05_3_equi, fit_y)
mse_3 = mean_squared_error(M_05_3_equi, fit_y)
print(parametros[0], parametros[1])

M_05_4_equi = y_05_4_b/y_05_4[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_05_4, M_05_4_equi)
n_05_4 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_05_4, parametros[0], n_05_4))
ax.plot(x_05_4, M_05_4_equi, 'o', label='Medida 4 data', color='y')
ax.plot(x_05_4, fit_y, '-', label='Medida 4 fit', color='y')
r2_kors_05_4 = r2_score(M_05_4_equi, fit_y)
mse_4 = mean_squared_error(M_05_4_equi, fit_y)
print(parametros[0], parametros[1])

ax.legend()
plt.show()

# %%
print('========================== R2 SCORE KORSMEYER-PEPPAS ==========================')
print('r2_05_1_Korsmeyer-Peppas =', r2_kors_05_1, " \t MSE = ", mse_1)
print('r2_05_2_Korsmeyer-Peppas =', r2_kors_05_2, " \t MSE = ", mse_2)
print('r2_05_3_Korsmeyer-Peppas =', r2_kors_05_3, " \t MSE = ", mse_3)
print('r2_05_4_Korsmeyer-Peppas =', r2_kors_05_4, " \t MSE = ", mse_4)
print('===============================================================================')
print('')
print('======== VALORES PARA n =======')
print('n_05_1 =', n_05_1)
print('n_05_2 =', n_05_2)
print('n_05_3 =', n_05_3)
print('n_05_4 =', n_05_4)
print('===============================')

print('=== Shapiro-Wilk ===')
print('H0: datos normales')
print('H1: datos no normales')
x = np.array([r2_kors_05_1,r2_kors_05_2,r2_kors_05_3,r2_kors_05_4])
res = stats.shapiro(x)
print('p-valor =', res.pvalue)
print('=== T-Student ===')
print('H0: La media es igual a 1')
print('H1: La media NO es igual a 1')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='two-sided')
print('p-valor =', t_student)
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='less')
print('p-valor =', t_student)
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='greater')
print('p-valor =', t_student)

# %% [markdown]
# #### HCl 10%

# %%
fig, ax = plt.subplots()

M_10_1_equi = y_10_1_b/y_10_1[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_10_1, M_10_1_equi)
n_10_1 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_10_1, parametros[0], n_10_1))
ax.plot(x_10_1, M_10_1_equi, 'o', label='Medida 1 data', color='b')
ax.plot(x_10_1, fit_y, '-', label='Medida 1 fit', color='b')
r2_kors_10_1 = r2_score(M_10_1_equi, fit_y)
mse_1 = mean_squared_error(M_10_1_equi, fit_y)
print(parametros[0], parametros[1])

M_10_2_equi = y_10_2_b/y_10_2[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_10_2, M_10_2_equi)
n_10_2 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_10_2, parametros[0], n_10_2))
ax.plot(x_10_2, M_10_2_equi, 'o', label='Medida 2 data', color='g')
ax.plot(x_10_2, fit_y, '-', label='Medida 2 fit', color='g')
r2_kors_10_2 = r2_score(M_10_2_equi, fit_y)
mse_2 = mean_squared_error(M_10_2_equi, fit_y)
print(parametros[0], parametros[1])

M_10_3_equi = y_10_3_b/y_10_3[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_10_3, M_10_3_equi)
n_10_3 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_10_3, parametros[0], n_10_3))
ax.plot(x_10_3, M_10_3_equi, 'o', label='Medida 3 data', color='r')
ax.plot(x_10_3, fit_y, '-', label='Medida 3 fit', color='r')
r2_kors_10_3 = r2_score(M_10_3_equi, fit_y)
mse_3 = mean_squared_error(M_10_3_equi, fit_y)
print(parametros[0], parametros[1])

M_10_4_equi = y_10_4_b/y_10_4[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_10_4, M_10_4_equi)
n_10_4 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_10_4, parametros[0], n_10_4))
ax.plot(x_10_4, M_10_4_equi, 'o', label='Medida 4 data', color='y')
ax.plot(x_10_4, fit_y, '-', label='Medida 4 fit', color='y')
r2_kors_10_4 = r2_score(M_10_4_equi, fit_y)
mse_4 = mean_squared_error(M_10_4_equi, fit_y)
print(parametros[0], parametros[1])

ax.legend()
plt.show()

# %%
print('========================== R2 SCORE KORSMEYER-PEPPAS ==========================')
print('r2_10_1_Korsmeyer-Peppas =', r2_kors_10_1, " \t MSE = ", mse_1)
print('r2_10_2_Korsmeyer-Peppas =', r2_kors_10_2, " \t MSE = ", mse_2)
print('r2_10_3_Korsmeyer-Peppas =', r2_kors_10_3, " \t MSE = ", mse_3)
print('r2_10_4_Korsmeyer-Peppas =', r2_kors_10_4, " \t MSE = ", mse_4)
print('===============================================================================')
print('')
print('======== VALORES PARA n =======')
print('n_10_1 =', n_10_1)
print('n_10_2 =', n_10_2)
print('n_10_3 =', n_10_3)
print('n_10_4 =', n_10_4)
print('===============================')

print('=== Shapiro-Wilk ===')
print('H0: datos normales')
print('H1: datos no normales')
x = np.array([r2_kors_10_1,r2_kors_10_2,r2_kors_10_3,r2_kors_10_4])
res = stats.shapiro(x)
print('p-valor =', res.pvalue)
print('=== T-Student ===')
print('H0: La media es igual a 1')
print('H1: La media NO es igual a 1')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='two-sided')
print('p-valor =', t_student)
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='less')
print('p-valor =', t_student)
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='greater')
print('p-valor =', t_student)

# %% [markdown]
# #### HCl 20%

# %%
fig, ax = plt.subplots()

M_20_1_equi = y_20_1_b/y_20_1[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_20_1, M_20_1_equi)
n_20_1 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_20_1, parametros[0], n_20_1))
ax.plot(x_20_1, M_20_1_equi, 'o', label='Medida 1 data', color='b')
ax.plot(x_20_1, fit_y, '-', label='Medida 1 fit', color='b')
r2_kors_20_1 = r2_score(M_20_1_equi, fit_y)
mse_1 = mean_squared_error(M_20_1_equi, fit_y)
print(parametros[0], parametros[1])

M_20_2_equi = y_20_2_b/y_20_2[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_20_2, M_20_2_equi)
n_20_2 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_20_2, parametros[0], n_20_2))
ax.plot(x_20_2, M_20_2_equi, 'o', label='Medida 2 data', color='g')
ax.plot(x_20_2, fit_y, '-', label='Medida 2 fit', color='g')
r2_kors_20_2 = r2_score(M_20_2_equi, fit_y)
mse_2 = mean_squared_error(M_20_2_equi, fit_y)
print(parametros[0], parametros[1])

M_20_3_equi = y_20_3_b/y_20_3[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_20_3, M_20_3_equi)
n_20_3 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_20_3, parametros[0], n_20_3))
ax.plot(x_20_3, M_20_3_equi, 'o', label='Medida 3 data', color='r')
ax.plot(x_20_3, fit_y, '-', label='Medida 3 fit', color='r')
r2_kors_20_3 = r2_score(M_20_3_equi, fit_y)
mse_3 = mean_squared_error(M_20_3_equi, fit_y)
print(parametros[0], parametros[1])

M_20_4_equi = y_20_4_b/y_20_4[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_20_4, M_20_4_equi)
n_20_4 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_20_4, parametros[0], n_20_4))
ax.plot(x_20_4, M_20_4_equi, 'o', label='Medida 4 data', color='y')
ax.plot(x_20_4, fit_y, '-', label='Medida 4 fit', color='y')
r2_kors_20_4 = r2_score(M_20_4_equi, fit_y)
mse_4 = mean_squared_error(M_20_4_equi, fit_y)
print(parametros[0], parametros[1])

ax.legend()
plt.show()

# %%
print('========================== R2 SCORE KORSMEYER-PEPPAS ==========================')
print('r2_20_1_Korsmeyer-Peppas =', r2_kors_20_1, " \t MSE = ", mse_1)
print('r2_20_2_Korsmeyer-Peppas =', r2_kors_20_2, " \t MSE = ", mse_2)
print('r2_20_3_Korsmeyer-Peppas =', r2_kors_20_3, " \t MSE = ", mse_3)
print('r2_20_4_Korsmeyer-Peppas =', r2_kors_20_4, " \t MSE = ", mse_4)
print('===============================================================================')
print('')
print('======== VALORES PARA n =======')
print('n_20_1 =', n_20_1)
print('n_20_2 =', n_20_2)
print('n_20_3 =', n_20_3)
print('n_20_4 =', n_20_4)
print('===============================')

print('=== Shapiro-Wilk ===')
print('H0: datos normales')
print('H1: datos no normales')
x = np.array([r2_kors_20_1,r2_kors_20_2,r2_kors_20_3,r2_kors_20_4])
res = stats.shapiro(x)
print('p-valor =', res.pvalue)
print('=== T-Student ===')
print('H0: La media es igual a 1')
print('H1: La media NO es igual a 1')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='two-sided')
print('p-valor =', t_student)
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='less')
print('p-valor =', t_student)
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='greater')
print('p-valor =', t_student)

# %% [markdown]
# #### HCl 30%

# %%
fig, ax = plt.subplots()

M_30_1_equi = y_30_1_b/y_30_1[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_30_1, M_30_1_equi)
n_30_1 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_30_1, parametros[0], n_30_1))
ax.plot(x_30_1, M_30_1_equi, 'o', label='Medida 1 data', color='b')
ax.plot(x_30_1, fit_y, '-', label='Medida 1 fit', color='b')
r2_kors_30_1 = r2_score(M_30_1_equi, fit_y)
mse_1 = mean_squared_error(M_30_1_equi, fit_y)
print(parametros[0], parametros[1])

M_30_2_equi = y_30_2_b/y_30_2[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_30_2, M_30_2_equi)
n_30_2 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_30_2, parametros[0], n_30_2))
ax.plot(x_30_2, M_30_2_equi, 'o', label='Medida 2 data', color='g')
ax.plot(x_30_2, fit_y, '-', label='Medida 2 fit', color='g')
r2_kors_30_2 = r2_score(M_30_2_equi, fit_y)
mse_2 = mean_squared_error(M_30_2_equi, fit_y)
print(parametros[0], parametros[1])

M_30_3_equi = y_30_3_b/y_30_3[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_30_3, M_30_3_equi)
n_30_3 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_30_3, parametros[0], n_30_3))
ax.plot(x_30_3, M_30_3_equi, 'o', label='Medida 3 data', color='r')
ax.plot(x_30_3, fit_y, '-', label='Medida 3 fit', color='r')
r2_kors_30_3 = r2_score(M_30_3_equi, fit_y)
mse_3 = mean_squared_error(M_30_3_equi, fit_y)
print(parametros[0], parametros[1])

M_30_4_equi = y_30_4_b/y_30_4[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_30_4, M_30_4_equi)
n_30_4 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_30_4, parametros[0], n_30_4))
ax.plot(x_30_4, M_30_4_equi, 'o', label='Medida 4 data', color='y')
ax.plot(x_30_4, fit_y, '-', label='Medida 4 fit', color='y')
r2_kors_30_4 = r2_score(M_30_4_equi, fit_y)
mse_4 = mean_squared_error(M_30_4_equi, fit_y)
print(parametros[0], parametros[1])

ax.legend()
plt.show()

# %%
print('========================== R2 SCORE KORSMEYER-PEPPAS ==========================')
print('r2_30_1_Korsmeyer-Peppas =', r2_kors_30_1, " \t MSE = ", mse_1)
print('r2_30_2_Korsmeyer-Peppas =', r2_kors_30_2, " \t MSE = ", mse_2)
print('r2_30_3_Korsmeyer-Peppas =', r2_kors_30_3, " \t MSE = ", mse_3)
print('r2_30_4_Korsmeyer-Peppas =', r2_kors_30_4, " \t MSE = ", mse_4)
print('===============================================================================')
print('')
print('======== VALORES PARA n =======')
print('n_30_1 =', n_30_1)
print('n_30_2 =', n_30_2)
print('n_30_3 =', n_30_3)
print('n_30_4 =', n_30_4)
print('===============================')

print('=== Shapiro-Wilk ===')
print('H0: datos normales')
print('H1: datos no normales')
x = np.array([r2_kors_30_1,r2_kors_30_2,r2_kors_30_3,r2_kors_30_4])
res = stats.shapiro(x)
print('p-valor =', res.pvalue)
print('=== T-Student ===')
print('H0: La media es igual a 1')
print('H1: La media NO es igual a 1')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='two-sided')
print('p-valor =', t_student)
print('H1: La media < ')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='less')
print('p-valor =', t_student)
print('H1: La media > ')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='greater')
print('p-valor =', t_student)

# %% [markdown]
# #### HCl 40%

# %%
fig, ax = plt.subplots()

M_40_1_equi = y_40_1_b/y_40_1[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_40_1, M_40_1_equi)
n_40_1 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_40_1, parametros[0], n_40_1))
ax.plot(x_40_1, M_40_1_equi, 'o', label='Medida 1 data', color='b')
ax.plot(x_40_1, fit_y, '-', label='Medida 1 fit', color='b')
r2_kors_40_1 = r2_score(M_40_1_equi, fit_y)
mse_1 = mean_squared_error(M_40_1_equi, fit_y)
print(parametros[0], parametros[1])

M_40_2_equi = y_40_2_b/y_40_2[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_40_2, M_40_2_equi)
n_40_2 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_40_2, parametros[0], n_40_2))
ax.plot(x_40_2, M_40_2_equi, 'o', label='Medida 2 data', color='g')
ax.plot(x_40_2, fit_y, '-', label='Medida 2 fit', color='g')
r2_kors_40_2 = r2_score(M_40_2_equi, fit_y)
mse_2 = mean_squared_error(M_40_2_equi, fit_y)
print(parametros[0], parametros[1])

M_40_3_equi = y_40_3_b/y_40_3[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_40_3, M_40_3_equi)
n_40_3 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_40_3, parametros[0], n_40_3))
ax.plot(x_40_3, M_40_3_equi, 'o', label='Medida 3 data', color='r')
ax.plot(x_40_3, fit_y, '-', label='Medida 3 fit', color='r')
r2_kors_40_3 = r2_score(M_40_3_equi, fit_y)
mse_3 = mean_squared_error(M_40_3_equi, fit_y)
print(parametros[0], parametros[1])

M_40_4_equi = y_40_4_b/y_40_4[-1]
parametros, covarianza = curve_fit(modelos.korsmeyer_peppas, x_40_4, M_40_4_equi)
n_40_4 = parametros[1]
fit_y = np.array(modelos.korsmeyer_peppas(x_40_4, parametros[0], n_40_4))
ax.plot(x_40_4, M_40_4_equi, 'o', label='Medida 4 data', color='y')
ax.plot(x_40_4, fit_y, '-', label='Medida 4 fit', color='y')
r2_kors_40_4 = r2_score(M_40_4_equi, fit_y)
mse_4 = mean_squared_error(M_40_4_equi, fit_y)
print(parametros[0], parametros[1])

ax.legend()
plt.show()

# %%
print('========================== R2 SCORE KORSMEYER-PEPPAS ==========================')
print('r2_40_1_Korsmeyer-Peppas =', r2_kors_40_1, " \t MSE = ", mse_1)
print('r2_40_2_Korsmeyer-Peppas =', r2_kors_40_2, " \t MSE = ", mse_2)
print('r2_40_3_Korsmeyer-Peppas =', r2_kors_40_3, " \t MSE = ", mse_3)
print('r2_40_4_Korsmeyer-Peppas =', r2_kors_40_4, " \t MSE = ", mse_4)
print('===============================================================================')
print('')
print('======== VALORES PARA n =======')
print('n_40_1 =', n_40_1)
print('n_40_2 =', n_40_2)
print('n_40_3 =', n_40_3)
print('n_40_4 =', n_40_4)
print('===============================')

print('=== Shapiro-Wilk ===')
print('H0: datos normales')
print('H1: datos no normales')
x = np.array([r2_kors_40_1,r2_kors_40_2,r2_kors_40_3,r2_kors_40_4])
res = stats.shapiro(x)
print('p-valor =', res.pvalue)
print('=== T-Student ===')
print('H0: La media es igual a 1')
print('H1: La media NO es igual a 1')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='two-sided')
print('p-valor =', t_student)
print('H1: La media < ')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='less')
print('p-valor =', t_student)
print('H1: La media > ')
t_student = stats.ttest_1samp(x, popmean=1.0, alternative='greater')
print('p-valor =', t_student)

# %% [markdown]
# ## GENERALIZED REGRESSION NEURONAL NETWORK

# %% [markdown]
# ### HCl 1%

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = np.concatenate((x,x,x))
y_train = np.concatenate((y_01_1, y_01_2, y_01_3))
x_test = x
y_test = y_01_4
#x_train, x_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(np.array(x).reshape((-1, 1))), 
#                                                    preprocessing.minmax_scale(np.array(y_01).reshape((-1, 1))), 
#                                                    test_size=0.25, random_state=42)

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
IGRNN = GRNN()
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1
                          )
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 1%\nMSE =", mse_1)

# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = np.concatenate((y_01_1, y_01_2, y_01_4))
y_test = y_01_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 1%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = np.concatenate((y_01_1, y_01_3, y_01_4))
y_test = y_01_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 1%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = np.concatenate((y_01_2, y_01_3, y_01_4))
y_test = y_01_1

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 1%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 155.0911928087792
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 7.831305072177104
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 45.437803597719416
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 239.67789336183787

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = x
y_train = y_01_1
x_test = x
y_test = y_01_1
#x_train, x_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(np.array(x).reshape((-1, 1))), 
#                                                    preprocessing.minmax_scale(np.array(y_01).reshape((-1, 1))), 
#                                                    test_size=0.25, random_state=42)

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
IGRNN = GRNN()
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1
                          )
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 1%\nMSE =", mse_1)

# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = y_01_2
y_test = y_01_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 1%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = y_01_3
y_test = y_01_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 1%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = y_01_4
y_test = y_01_4

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 1%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.6410340489373486
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.5044209184739319
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.6236727400392622
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.6263103752528402

# %%
fig, ax = plt.subplots()
ax.plot(x_test, y_test_1, 'o', label='Medida 1 - datos', color='b')
ax.plot(x_test, fit_y_1, '-', label='Medida 1 - modelo', color='b')
ax.plot(x_test, y_test_2, 'o', label='Medida 2 - datos', color='g')
ax.plot(x_test, fit_y_2, '-', label='Medida 2 - modelo', color='g')
ax.plot(x_test, y_test_3, 'o', label='Medida 3 - datos', color='r')
ax.plot(x_test, fit_y_3, '-', label='Medida 3 - modelo', color='r')
ax.plot(x_test, y_test_4, 'o', label='Medida 4 - datos', color='y')
ax.plot(x_test, fit_y_4, '-', label='Medida 4 - modelo', color='y')

plt.xlabel('Tiempo (horas)')
plt.ylabel('Concentracion (microgramos/cm2)')
ax.legend()
plt.show()

# %%
r2_01_1 = r2_score(y_test_1, fit_y_1)
r2_01_2 = r2_score(y_test_2, fit_y_2)
r2_01_3 = r2_score(y_test_3, fit_y_3)
r2_01_4 = r2_score(y_test_4, fit_y_4)

print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_grnn_1_first =', r2_01_1, ' \t MSE =', mse_1)
print('r2_grnn_2_first =', r2_01_2, ' \t MSE =', mse_2)
print('r2_grnn_3_first =', r2_01_3, ' \t MSE =', mse_3)
print('r2_grnn_4_first =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
print('MEDIA_R2=', statistics.mean([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('SD_R2=', statistics.stdev([r2_01_1, r2_01_2, r2_01_3, r2_01_4]))
print('MEDIA_MSE=', statistics.mean([mse_1, mse_2, mse_3, mse_4]))
print('SD_MSE=', statistics.stdev([mse_1, mse_2, mse_3, mse_4]))
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_grnn_1_first = 0.9861523855829711  	 MSE = 155.0911928087792
# r2_grnn_2_first = 0.9993705700650252  	 MSE = 7.831305072177104
# r2_grnn_3_first = 0.9963206117500147  	 MSE = 45.437803597719416
# r2_grnn_4_first = 0.9821305167247899  	 MSE = 239.67789336183787
# ...
# MEDIA_R2= 0.9909935210307003
# SD_R2= 0.008176027637859665
# MEDIA_MSE= 112.0095487101284
# SD_MSE= 105.57799325482935

# %% [markdown]
# ### HCl 5%

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = np.concatenate((x,x,x))
y_train = np.concatenate((y_05_1, y_05_2, y_05_3))
x_test = x
y_test = y_05_4

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 5%\nMSE =", mse_1)


# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = np.concatenate((y_05_1, y_05_2, y_05_4))
y_test = y_05_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 5%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = np.concatenate((y_05_1, y_05_3, y_05_4))
y_test = y_05_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 5%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = np.concatenate((y_05_2, y_05_3, y_05_4))
y_test = y_05_1

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 5%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 5%
# MSE = 131.26296449135813
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 5%
# MSE = 6.245938116307846
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 5%
# MSE = 3.7458383624239118
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 5%
# MSE = 179.0092623304848

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = x
y_train = y_05_1
x_test = x
y_test = y_05_1
#x_train, x_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(np.array(x).reshape((-1, 1))), 
#                                                    preprocessing.minmax_scale(np.array(y_01).reshape((-1, 1))), 
#                                                    test_size=0.25, random_state=42)

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
IGRNN = GRNN()
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1
                          )
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 1%\nMSE =", mse_1)

# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = y_05_2
y_test = y_05_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 1%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = y_05_3
y_test = y_05_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 1%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = y_05_4
y_test = y_05_4

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 1%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.6313800170129267
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.5176938559411532
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.4723009086355887
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.44603699217553006

# %%
fig, ax = plt.subplots()
ax.plot(x_test, y_test_1, 'o', label='Medida 1 data', color='b')
ax.plot(x_test, fit_y_1, '-', label='Medida 1 fit', color='b')
ax.plot(x_test, y_test_2, 'o', label='Medida 2 data', color='g')
ax.plot(x_test, fit_y_2, '-', label='Medida 2 fit', color='g')
ax.plot(x_test, y_test_3, 'o', label='Medida 3 data', color='r')
ax.plot(x_test, fit_y_3, '-', label='Medida 3 fit', color='r')
ax.plot(x_test, y_test_4, 'o', label='Medida 4 data', color='y')
ax.plot(x_test, fit_y_4, '-', label='Medida 4 fit', color='y')

plt.xlabel('Tiempo (horas)')
plt.ylabel('Concentracion (microgramos/cm2)')
ax.legend()
plt.show()

# %%
r2_01_1 = r2_score(y_test_1, fit_y_1)
r2_01_2 = r2_score(y_test_2, fit_y_2)
r2_01_3 = r2_score(y_test_3, fit_y_3)
r2_01_4 = r2_score(y_test_4, fit_y_4)

print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_grnn_1_first =', r2_01_1, ' \t MSE =', mse_1)
print('r2_grnn_2_first =', r2_01_2, ' \t MSE =', mse_2)
print('r2_grnn_3_first =', r2_01_3, ' \t MSE =', mse_3)
print('r2_grnn_4_first =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_grnn_1_first = 0.9867313669447333  	 MSE = 131.26296449135813
# r2_grnn_2_first = 0.9994338378088528  	 MSE = 6.245938116307846
# r2_grnn_3_first = 0.9996555448322494  	 MSE = 3.7458383624239118
# r2_grnn_4_first = 0.9855067693594378  	 MSE = 179.0092623304848
# ...

# %% [markdown]
# ### HCl 10%

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = np.concatenate((x,x,x))
y_train = np.concatenate((y_10_1, y_10_2, y_10_3))
x_test = x
y_test = y_10_4

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 10%\nMSE =", mse_1)


# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = np.concatenate((y_10_1, y_10_2, y_10_4))
y_test = y_10_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 10%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = np.concatenate((y_10_1, y_10_3, y_10_4))
y_test = y_10_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 10%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = np.concatenate((y_10_2, y_10_3, y_10_4))
y_test = y_10_1

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 10%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 10%
# MSE = 6.746264319181579
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 10%
# MSE = 27.636670622650648
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 10%
# MSE = 158.4396803957342
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 10%
# MSE = 97.53975899727966

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = x
y_train = y_10_1
x_test = x
y_test = y_10_1
#x_train, x_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(np.array(x).reshape((-1, 1))), 
#                                                    preprocessing.minmax_scale(np.array(y_01).reshape((-1, 1))), 
#                                                    test_size=0.25, random_state=42)

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
IGRNN = GRNN()
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1
                          )
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 1%\nMSE =", mse_1)

# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = y_10_2
y_test = y_10_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 1%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = y_10_3
y_test = y_10_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 1%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = y_10_4
y_test = y_10_4

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 1%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.5190486821345256
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.3580453771557887
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.44645540858933025
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.49150096638457363

# %%
fig, ax = plt.subplots()
ax.plot(x_test, y_test_1, 'o', label='Medida 1 data', color='b')
ax.plot(x_test, fit_y_1, '-', label='Medida 1 fit', color='b')
ax.plot(x_test, y_test_2, 'o', label='Medida 2 data', color='g')
ax.plot(x_test, fit_y_2, '-', label='Medida 2 fit', color='g')
ax.plot(x_test, y_test_3, 'o', label='Medida 3 data', color='r')
ax.plot(x_test, fit_y_3, '-', label='Medida 3 fit', color='r')
ax.plot(x_test, y_test_4, 'o', label='Medida 4 data', color='y')
ax.plot(x_test, fit_y_4, '-', label='Medida 4 fit', color='y')

plt.xlabel('Tiempo (horas)')
plt.ylabel('Concentracion (microgramos/cm2)')
ax.legend()
plt.show()

# %%
r2_01_1 = r2_score(y_test_1, fit_y_1)
r2_01_2 = r2_score(y_test_2, fit_y_2)
r2_01_3 = r2_score(y_test_3, fit_y_3)
r2_01_4 = r2_score(y_test_4, fit_y_4)

print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_grnn_1_first =', r2_01_1, ' \t MSE =', mse_1)
print('r2_grnn_2_first =', r2_01_2, ' \t MSE =', mse_2)
print('r2_grnn_3_first =', r2_01_3, ' \t MSE =', mse_3)
print('r2_grnn_4_first =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_grnn_1_first = 0.9992466374746818  	 MSE = 6.746264319181579
# r2_grnn_2_first = 0.996925345068344  	 MSE = 27.636670622650648
# r2_grnn_3_first = 0.9823849466300244  	 MSE = 158.4396803957342
# r2_grnn_4_first = 0.990178775407826  	 MSE = 97.53975899727966
# ...

# %% [markdown]
# ### HCl 20%

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = np.concatenate((x,x,x))
y_train = np.concatenate((y_20_1, y_20_2, y_20_3))
x_test = x
y_test = y_20_4

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 20%\nMSE =", mse_1)


# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = np.concatenate((y_20_1, y_20_2, y_20_4))
y_test = y_20_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 20%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = np.concatenate((y_20_1, y_20_3, y_20_4))
y_test = y_20_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 20%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = np.concatenate((y_20_2, y_20_3, y_20_4))
y_test = y_20_1

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 20%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 20%
# MSE = 116.84340414819206
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 20%
# MSE = 7.9671630651282435
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 20%
# MSE = 183.32378652574144
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 20%
# MSE = 504.43217957178234

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = x
y_train = y_20_1
x_test = x
y_test = y_20_1
#x_train, x_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(np.array(x).reshape((-1, 1))), 
#                                                    preprocessing.minmax_scale(np.array(y_01).reshape((-1, 1))), 
#                                                    test_size=0.25, random_state=42)

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
IGRNN = GRNN()
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1
                          )
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 1%\nMSE =", mse_1)

# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = y_20_2
y_test = y_20_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 1%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = y_20_3
y_test = y_20_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 1%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = y_20_4
y_test = y_20_4

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 1%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.26011101813690823
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.18854529009113846
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.2707635344255367
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.20608886182201824

# %%
fig, ax = plt.subplots()
ax.plot(x_test, y_test_1, 'o', label='Medida 1 data', color='b')
ax.plot(x_test, fit_y_1, '-', label='Medida 1 fit', color='b')
ax.plot(x_test, y_test_2, 'o', label='Medida 2 data', color='g')
ax.plot(x_test, fit_y_2, '-', label='Medida 2 fit', color='g')
ax.plot(x_test, y_test_3, 'o', label='Medida 3 data', color='r')
ax.plot(x_test, fit_y_3, '-', label='Medida 3 fit', color='r')
ax.plot(x_test, y_test_4, 'o', label='Medida 4 data', color='y')
ax.plot(x_test, fit_y_4, '-', label='Medida 4 fit', color='y')

plt.xlabel('Tiempo (horas)')
plt.ylabel('Concentracion (microgramos/cm2)')
ax.legend()
plt.show()

# %%
r2_01_1 = r2_score(y_test_1, fit_y_1)
r2_01_2 = r2_score(y_test_2, fit_y_2)
r2_01_3 = r2_score(y_test_3, fit_y_3)
r2_01_4 = r2_score(y_test_4, fit_y_4)

print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_grnn_1_first =', r2_01_1, ' \t MSE =', mse_1)
print('r2_grnn_2_first =', r2_01_2, ' \t MSE =', mse_2)
print('r2_grnn_3_first =', r2_01_3, ' \t MSE =', mse_3)
print('r2_grnn_4_first =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_grnn_1_first = 0.9821005786077934  	 MSE = 116.84340414819206
# r2_grnn_2_first = 0.9988826038322398  	 MSE = 7.9671630651282435
# r2_grnn_3_first = 0.9721549962894738  	 MSE = 183.32378652574144
# r2_grnn_4_first = 0.934088397384755  	 MSE = 504.43217957178234
# ...

# %% [markdown]
# ### HCl 30%

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = np.concatenate((x,x,x))
y_train = np.concatenate((y_30_1, y_30_2, y_30_3))
x_test = x
y_test = y_30_4

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 30%\nMSE =", mse_1)


# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = np.concatenate((y_30_1, y_30_2, y_30_4))
y_test = y_30_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 30%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = np.concatenate((y_30_1, y_30_3, y_30_4))
y_test = y_30_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 30%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = np.concatenate((y_30_2, y_30_3, y_30_4))
y_test = y_30_1

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 30%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 30%
# MSE = 54.671425115348704
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 30%
# MSE = 116.80654781163
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 30%
# MSE = 15.925537270853937
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 30%
# MSE = 8.698160864807136

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = x
y_train = y_30_1
x_test = x
y_test = y_30_1
#x_train, x_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(np.array(x).reshape((-1, 1))), 
#                                                    preprocessing.minmax_scale(np.array(y_01).reshape((-1, 1))), 
#                                                    test_size=0.25, random_state=42)

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
IGRNN = GRNN()
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1
                          )
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 1%\nMSE =", mse_1)

# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = y_30_2
y_test = y_30_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 1%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = y_30_3
y_test = y_30_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 1%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = y_30_4
y_test = y_30_4

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 1%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.1070768881024257
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.15376686780513976
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.21889857718043892
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.13083951916567577

# %%
fig, ax = plt.subplots()
ax.plot(x_test, y_test_1, 'o', label='Medida 1 data', color='b')
ax.plot(x_test, fit_y_1, '-', label='Medida 1 fit', color='b')
ax.plot(x_test, y_test_2, 'o', label='Medida 2 data', color='g')
ax.plot(x_test, fit_y_2, '-', label='Medida 2 fit', color='g')
ax.plot(x_test, y_test_3, 'o', label='Medida 3 data', color='r')
ax.plot(x_test, fit_y_3, '-', label='Medida 3 fit', color='r')
ax.plot(x_test, y_test_4, 'o', label='Medida 4 data', color='y')
ax.plot(x_test, fit_y_4, '-', label='Medida 4 fit', color='y')

plt.xlabel('Tiempo (horas)')
plt.ylabel('Concentracion (microgramos/cm2)')
ax.legend()
plt.show()

# %%
r2_01_1 = r2_score(y_test_1, fit_y_1)
r2_01_2 = r2_score(y_test_2, fit_y_2)
r2_01_3 = r2_score(y_test_3, fit_y_3)
r2_01_4 = r2_score(y_test_4, fit_y_4)

print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_grnn_1_first =', r2_01_1, ' \t MSE =', mse_1)
print('r2_grnn_2_first =', r2_01_2, ' \t MSE =', mse_2)
print('r2_grnn_3_first =', r2_01_3, ' \t MSE =', mse_3)
print('r2_grnn_4_first =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_grnn_1_first = 0.9885245534995984  	 MSE = 54.671425115348704
# r2_grnn_2_first = 0.9798067919731343  	 MSE = 116.80654781163
# r2_grnn_3_first = 0.9970957326960799  	 MSE = 15.925537270853937
# r2_grnn_4_first = 0.9982616140799582  	 MSE = 8.698160864807136
# ...

# %% [markdown]
# ### HCl 40%

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = np.concatenate((x,x,x))
y_train = np.concatenate((y_40_1, y_40_2, y_40_3))
x_test = x
y_test = y_40_4

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 40%\nMSE =", mse_1)


# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = np.concatenate((y_40_1, y_40_2, y_40_4))
y_test = y_40_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 40%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = np.concatenate((y_40_1, y_40_3, y_40_4))
y_test = y_40_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 40%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = np.concatenate((y_40_2, y_40_3, y_40_4))
y_test = y_40_1

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 40%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 40%
# MSE = 33.20301024584087
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 40%
# MSE = 5.441000508862832
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 40%
# MSE = 47.21019109485982
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 40%
# MSE = 5.659085721224621

# %%
# Entrenamiento: 1, 2, 3 --- Validacion: 4
x_train = x
y_train = y_40_1
x_test = x
y_test = y_40_1
#x_train, x_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(np.array(x).reshape((-1, 1))), 
#                                                    preprocessing.minmax_scale(np.array(y_01).reshape((-1, 1))), 
#                                                    test_size=0.25, random_state=42)

x_train = np.array(x_train).reshape((-1, 1))
y_train = np.array(y_train).reshape((-1, 1))
x_test = np.array(x_test).reshape((-1, 1))
y_test_1 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
IGRNN = GRNN()
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1
                          )
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_1 = best_model.predict(x_test)

mse_1 = mean_squared_error(y_test_1, fit_y_1)
print("HCl 1%\nMSE =", mse_1)

# Entrenamiento: 1, 2, 4 --- Validacion: 3
y_train = y_40_2
y_test = y_40_2

y_train = np.array(y_train).reshape((-1, 1))
y_test_2 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_2 = best_model.predict(x_test)

mse_2 = mean_squared_error(y_test_2, fit_y_2)
print("HCl 1%\nMSE =", mse_2)


# Entrenamiento: 1, 3, 4 --- Validacion: 2
y_train = y_40_3
y_test = y_40_3

y_train = np.array(y_train).reshape((-1, 1))
y_test_3 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_3 = best_model.predict(x_test)

mse_3 = mean_squared_error(y_test_3, fit_y_3)
print("HCl 1%\nMSE =", mse_3)


# Entrenamiento: 2, 3, 4 --- Validacion: 1
y_train = y_40_4
y_test = y_40_4

y_train = np.array(y_train).reshape((-1, 1))
y_test_4 = np.array(y_test).reshape((-1, 1))

# Isotropic GRNN with a Grid Search Cross validation to select the optimal bandwidth
grid_IGRNN.fit(x_train, np.array(y_train).ravel())
best_model = grid_IGRNN.best_estimator_
fit_y_4 = best_model.predict(x_test)

mse_4 = mean_squared_error(y_test_4, fit_y_4)
print("HCl 1%\nMSE =", mse_4)
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.05958877533401361
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.04930228909168765
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.08935649997535379
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# HCl 1%
# MSE = 0.13123906236869515

# %%
fig, ax = plt.subplots()
ax.plot(x_test, y_test_1, 'o', label='Medida 1 data', color='b')
ax.plot(x_test, fit_y_1, '-', label='Medida 1 fit', color='b')
ax.plot(x_test, y_test_2, 'o', label='Medida 2 data', color='g')
ax.plot(x_test, fit_y_2, '-', label='Medida 2 fit', color='g')
ax.plot(x_test, y_test_3, 'o', label='Medida 3 data', color='r')
ax.plot(x_test, fit_y_3, '-', label='Medida 3 fit', color='r')
ax.plot(x_test, y_test_4, 'o', label='Medida 4 data', color='y')
ax.plot(x_test, fit_y_4, '-', label='Medida 4 fit', color='y')

plt.xlabel('Tiempo (horas)')
plt.ylabel('Concentracion (microgramos/cm2)')
ax.legend()
plt.show()

# %%
r2_01_1 = r2_score(y_test_1, fit_y_1)
r2_01_2 = r2_score(y_test_2, fit_y_2)
r2_01_3 = r2_score(y_test_3, fit_y_3)
r2_01_4 = r2_score(y_test_4, fit_y_4)

print('====================== R2 SCORE FIRST_ORDER ======================')
print('r2_grnn_1_first =', r2_01_1, ' \t MSE =', mse_1)
print('r2_grnn_2_first =', r2_01_2, ' \t MSE =', mse_2)
print('r2_grnn_3_first =', r2_01_3, ' \t MSE =', mse_3)
print('r2_grnn_4_first =', r2_01_4, ' \t MSE =', mse_4)
print('==================================================================')
# Out:
# ====================== R2 SCORE FIRST_ORDER ======================
# r2_grnn_1_first = 0.9915364409774591  	 MSE = 33.20301024584087
# r2_grnn_2_first = 0.9985443672868662  	 MSE = 5.441000508862832
# r2_grnn_3_first = 0.9880348952255152  	 MSE = 47.21019109485982
# r2_grnn_4_first = 0.9984474242429421  	 MSE = 5.659085721224621
# ...
